# %% [markdown]
# # Data loading and cleaning

# %% [markdown]
# **Note:** To run the notebook upload given "train.csv" and "hindistatements_week2.csv" for phase 1 in the drive inside collaboratory folder.

# %%
import string
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import numpy as np
import pandas as pd

import random
import joblib
import pickle

# %%
device = torch.device("cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# We will read the data from drive directly. For safety we will make a copy of the data and drop the first column from the data.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=pd.read_csv("/content/drive/MyDrive/Temp/Hindi3/train-set.csv")
data_copy=data.copy()
data.drop(data.columns[0],axis=1,inplace=True)
data.head()
# Out:
#                                                hindi  \
# 0  एल सालवाडोर मे, जिन दोनो पक्षों ने सिविल-युद्ध...
# 1                मैं उनके साथ कोई लेना देना नहीं है.
# 2                                         -हटाओ रिक.
# 3               क्योंकि यह एक खुशियों भरी फ़िल्म है.
# 4                   The thought reaching the eyes...
#
#                                              english
# 0  In El Salvador, both sides that withdrew from ...
# 1                    I have nothing to do with them.
# 2                                   Fuck them, Rick.
# 3                         Because it's a happy film.
# 4                   The thought reaching the eyes...

# %%
data.shape
# Out:
# (102322, 2)

# %% [markdown]
# **Creating columns for sentence length for both Hindi and English**
#
# Sentence length can play important role in cleaning the data, so we can create two new columns for lengths of hindi and english sentences.

# %%
data['len_hindi']=data['hindi'].apply(lambda x:len(x.split(' ')))
data['len_english']=data['english'].apply(lambda x: len(x.split(' ')))

# %% [markdown]
# **Checking for null values**
#
# checking for null values is generally the first step in the data analaysis. Here also we can check if any null values are present in the given dataset or not.

# %%
data.isnull().sum()
# Out:
# hindi          0
# english        0
# len_hindi      0
# len_english    0
# dtype: int64

# %% [markdown]
# There is no null values present in the data

# %% [markdown]
# **Dropping duplicates from the data**
#
# It may be the case that there are some duplicate entries present in the dataset. We can remove such entries.

# %%
print(f"Shape of the dataset before removing the duplicates: {data.shape}")
data.drop_duplicates(inplace=True)
print(f"Shape of the dataset after removing the duplicates: {data.shape}")
# Out:
# Shape of the dataset before removing the duplicates: (102322, 4)
# Shape of the dataset after removing the duplicates: (102296, 4)

# %% [markdown]
# We can see there were some duplicates present in the dataset.

# %% [markdown]
# **Converting all chars in the lowercase**
#
# We can perform lowercase normalization on the whole data.

# %%
data['hindi']=data['hindi'].apply(lambda x: x.lower())
data['english']=data['english'].apply(lambda x: x.lower())

# %% [markdown]
# **Removing punctuations**
#
# There are different kinds of punctuations present in both hindi and english sentences. It's better to remove such punctuations in the data cleaning.

# %%
def remove_punctuations(sentence):
    punctuations=list(string.punctuation)
    cleaned=""
    for letter in sentence:
        if letter not in punctuations:
            cleaned+=letter
    return cleaned

# %%
data['hindi']=data['hindi'].apply(lambda x: remove_punctuations(x))
data['english']=data['english'].apply(lambda x: remove_punctuations(x))

# %% [markdown]
# **Removing mixed sentences (those samples which have english words in the hindi sentences)**
#
# On observing the data, we find out that there are some samples in which english words are present between the hindi sentences. We treat these sentences as outliers and can remove them from the dataset.

# %%
def is_mixed(sentence):
    letters="abcdefghijklmnopqrstuvwxyz"
    for ch in letters:
        if ch in sentence:
            return True
    return False

# %%
data['is_mixed']=data['hindi'].apply(lambda x : is_mixed(x))
data.head()
# Out:
#                                                hindi  \
# 0  एल सालवाडोर मे जिन दोनो पक्षों ने सिविलयुद्ध स...
# 1                 मैं उनके साथ कोई लेना देना नहीं है
# 2                                           हटाओ रिक
# 3                क्योंकि यह एक खुशियों भरी फ़िल्म है
# 4                      the thought reaching the eyes
#
#                                              english  len_hindi  len_english  \
# 0  in el salvador both sides that withdrew from t...         22           23
# 1                     i have nothing to do with them          8            7
# 2                                     fuck them rick          2            3
# 3                           because its a happy film          7            5
# 4                      the thought reaching the eyes          5            5
#
#    is_mixed
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True

# %%
data['is_mixed'].value_counts(normalize=True)*100
# Out:
# False    94.430867
# True      5.569133
# Name: is_mixed, dtype: float64

# %%
data=data[data['is_mixed']==False]

# %% [markdown]
# **Changing the Encoding of the data**
#
# The data may have some 'unicode' encoding. We need to change the encoding for processing of the data.

# %%
data['hindi']=data['hindi'].str.encode('utf-8',errors='ignore').str.decode('utf-8')
data['english']=data['english'].str.encode('ascii',errors='ignore').str.decode('utf-8')

# %% [markdown]
# **Dropping any row having NULL values**

# %%
null_indices=[]
for index,rows in data.iterrows():
    is_null=rows.isnull()
    if is_null.any():
        null_indices.append(index)

# %%
data.drop(null_indices,inplace=True)

# %% [markdown]
# **Saving the processed Dataframe**
#
# We will save this processed dataset into drive, so we don't have to repeat these steps again and again.

# %%
data.to_csv("/content/drive/MyDrive/Temp/Hindi3/processed.csv")

# %% [markdown]
# # Loading processed Dataset and Vocabulary building
#
# We will load the processed dataframe directly and build the vocabulary for source and target language.
#
# ### References:
# 1. https://pytorch.org/tutorials/intermediate/seq2seq_translation_tutorial.html
# 2. https://www.youtube.com/watch?v=B8g-PNT2W2Q
# 3. https://www.youtube.com/watch?v=EoGUlvhRYpk

# %%
data=pd.read_csv('/content/drive/MyDrive/Temp/Hindi3/processed.csv')

# %%
null_indices=[]
for index,rows in data.iterrows():
    is_null=rows.isnull()
    if is_null.any():
        null_indices.append(index)

data.drop(null_indices,inplace=True)

# %%
# We need to create dictionaries for both Hindi and English languages. We will also assign
# indexes to all the words in vocabulary.
SOS_token=0
EOS_token=1
PAD_token=2
MAX_LENGTH=10

class Vocab_class:
    def __init__(self):
        self.word_to_index={"<SOS>":0,"<EOS>":1,"<PAD>":2,"<UKN>":3}  #dict to map each token to an index
        self.word_counts={} # will keep track of each token in the vocabulary
        self.index_to_word={0:"<SOS>", 1:"<EOS>", 2:"<PAD>", 3:"<UKN>"} # will map each index to a token
        self.num_of_words=4

    def sentence_add(self, sentence): # function to add the words of a sentence into the vocabulary
        words=sentence.split(" ")
        for word in words:
            if word not in self.word_to_index:
                self.word_to_index[word]=self.num_of_words
                self.word_counts[word]=1

                self.index_to_word[self.num_of_words]=word
                self.num_of_words+=1
            else:
                self.word_counts[word]+=1

# %%
hindi_lang=Vocab_class()
eng_lang=Vocab_class()
pairs=[]  # this list will contain sentences after it has been added to vocabulary.
for index,row in data.iterrows():
    if row['len_hindi']<MAX_LENGTH and row['len_english']<MAX_LENGTH: # taking sentences only whose length is less than the MAX_LENGTH
        pair=[row['hindi'].strip(), row['english'].strip()]
        hin_extra=MAX_LENGTH-len(row['hindi'].strip().split(" "))
        eng_extra=MAX_LENGTH-len(row['english'].strip().split(" "))
        hindi_lang.sentence_add(pair[0])
        eng_lang.sentence_add(pair[1])
        pair[0]=pair[0].split(" ")
        pair[0].insert(0,"<SOS>")
        pair[0].append("<EOS>")
        pair[0]=pair[0]+["<PAD>"]*(hin_extra)

        pair[1]=pair[1].split(" ")
        pair[1].insert(0,"<SOS>")
        pair[1].append("<EOS>")
        pair[1]=pair[1]+["<PAD>"]*(eng_extra)

        # pair[1]=pair[1].split(" ")+["PAD"]*eng_extra
        pair[0]=" ".join(pair[0])
        pair[1]=" ".join(pair[1])
        pairs.append(pair)    #padded sentence pair is added

# %%
# checking how many words are present in both of the vocabularies
print(f"Hindi vocabulary size : {hindi_lang.num_of_words}")
print(f"English vocabulary size: {eng_lang.num_of_words}")
# Out:
# Hindi vocabulary size : 19757
# English vocabulary size: 14747

# %%
joblib.dump(hindi_lang, '/content/drive/MyDrive/Temp/Hindi3/Model/hindi_lang.joblib')
joblib.dump(eng_lang, '/content/drive/MyDrive/Temp/Hindi3/Model/eng_lang.joblib')

pickle.dump(hindi_lang, open('/content/drive/MyDrive/Temp/Hindi3/Model/hindi_lang.pkl', 'wb'))
pickle.dump(eng_lang, open('/content/drive/MyDrive/Temp/Hindi3/Model/eng_lang.pkl', 'wb'))

# %%
def pair_to_tensor(pair):
    '''
    A function to convert a given pair to tensors corresponding to index in vocabulary
    '''
    hindi_sentence=pair[0]
    eng_sentence=pair[1]
    indexes_hindi=[hindi_lang.word_to_index[word] for word in hindi_sentence.split(' ')]
    indexes_eng=[eng_lang.word_to_index[word] for word in eng_sentence.split(' ')]
    hindi_tensor=torch.tensor(indexes_hindi, dtype=torch.long, device=device).view(-1,1)
    eng_tensor=torch.tensor(indexes_eng, dtype=torch.long, device=device).view(-1,1)
    return (hindi_tensor, eng_tensor)

# %%
hin_tensors=[]
eng_tensors=[]
for pair in pairs:  #will convert each pair into tensors for further processing
    hin,eng=pair_to_tensor(pair)
    hin_tensors.append(hin)
    eng_tensors.append(eng)

# %% [markdown]
# # Seq2Seq Model Implementation
#
# #### References:
# 1. https://machinelearningmastery.com/encoder-decoder-recurrent-neural-network-models-neural-machine-translation/
# 2. https://towardsdatascience.com/understanding-encoder-decoder-sequence-to-sequence-model-679e04af4346
#
#
# ### Encoder RNN Implementation

# %%
### Encoder RNN Implementation
class EncoderLSTM(nn.Module):
    def __init__(self,size_input,size_embbeding,size_hidden,layers,p):
        super(EncoderLSTM,self).__init__()
        self.size_input=size_input
        self.size_embbeding=size_embbeding
        self.size_hidden=size_hidden
        self.layers=layers
        self.dropout=nn.Dropout(p)
        self.tag=True

        self.embbed_layer=nn.Embedding(self.size_input,self.size_embbeding)
        self.lstm=nn.LSTM(self.size_embbeding,self.size_hidden,self.layers,dropout=p)

    def forward(self, x):
        # print(x.shape)
        embbeding=self.dropout(self.embbed_layer(x))
        # print(embbeding.shape)
        output, (hidden_st,cell_st) = self.lstm(embbeding)
        return hidden_st, cell_st # will return only hidden and cell state from the Encoder

# %% [markdown]
# ### Decoder RNN Implementation

# %%
### Decoder RNN Implementation
class DecoderLSTM(nn.Module):
    def __init__(self,size_input,size_embbeding,size_hidden,layers,p,size_output):
        super(DecoderLSTM,self).__init__()
        self.size_input=size_input
        self.size_embbeding=size_embbeding
        self.size_hidden=size_hidden
        self.layers=layers
        self.size_output=size_output
        self.dropout=nn.Dropout(p)
        # self.tag=True

        self.embbed_layer=nn.Embedding(self.size_input,self.size_embbeding) # input_size X embedding_size
        self.lstm=nn.LSTM(self.size_embbeding,self.size_hidden,self.layers,dropout=p) #embedding_size * hidden_size
        self.fc=nn.Linear(self.size_hidden,self.size_output) # hidden_size*output_size

    def forward(self,x,hidden_st,cell_st):
        x=x.unsqueeze(0)
        embbeding=self.dropout(self.embbed_layer(x))
        outputs, (hidden_st, cell_st) = self.lstm(embbeding, (hidden_st,cell_st))
        preds=self.fc(outputs)
        preds=preds.squeeze(0)
        return preds,hidden_st,cell_st

# %% [markdown]
# ### Encoder-Decoder Interface Implementation

# %%
class Seq2seq_model(nn.Module):
    def __init__(self,encoder_net,decoder_net):
        super(Seq2seq_model,self).__init__()
        self.encoder_net=encoder_net
        self.decoder_net=decoder_net

    def forward(self,src,target,teacher_forcing=0.5):
        batch_length=src.shape[1]
        target_len=target.shape[0]
        target_vocab_len=eng_lang.num_of_words

        output_tensor=torch.zeros(target_len,batch_length,target_vocab_len).to(device)
        hidden_st_enc, cell_st_enc=self.encoder_net(src)
        x=target[0]

        for i in range(1,target_len):
            output,hidden_st_dec,cell_st_dec=self.decoder_net(x,hidden_st_enc,cell_st_enc)
            output_tensor[i]=output
            pred=output.argmax(1)
            x=target[i] if random.random()<teacher_forcing else pred #teacher forcing is used with probability 0.5

        return output_tensor

# %% [markdown]
# **Creating objects of Encoder, Decoder and Seq2Seq model**

# %%
encoder_ip_size=hindi_lang.num_of_words #equal to hindi vocab size
encoder_embbeding_size=400  #encoder embedding size, tried various values to finalize this value
encoder_hidden_size=512 # previously tried with 1024 but this value gives better score
encoder_layers=1  # LSTM layers=1
encoder_dropout=float(0.5)  # dropout if applied, for layers=1 no need of dropout

encoder_obj=EncoderLSTM(encoder_ip_size, encoder_embbeding_size, encoder_hidden_size, encoder_layers,
                        encoder_dropout).to(device) # creating object of EncoderLSTM class

print(encoder_obj)
# Out:
# EncoderLSTM(
#   (dropout): Dropout(p=0.5, inplace=False)
#   (embbed_layer): Embedding(19757, 400)
#   (lstm): LSTM(400, 512, dropout=0.5)
# )
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "

# %%
# embedding size, hidden_size and number of layers will be same as of Encoders
decoder_ip_size=eng_lang.num_of_words
decoder_embbed_size=400
decoder_hidden_size=512
decoder_layers=1
decoder_dropout=float(0.5)
decoder_op_size=eng_lang.num_of_words

decoder_obj=DecoderLSTM(decoder_ip_size,decoder_embbed_size,decoder_hidden_size,
                        decoder_layers, decoder_dropout, decoder_op_size).to(device)  # creating object of DecoderLSTM

print(decoder_obj)
# Out:
# DecoderLSTM(
#   (dropout): Dropout(p=0.5, inplace=False)
#   (embbed_layer): Embedding(14747, 400)
#   (lstm): LSTM(400, 512, dropout=0.5)
#   (fc): Linear(in_features=512, out_features=14747, bias=True)
# )

# %%
model=Seq2seq_model(encoder_obj, decoder_obj)
print(model)
# Out:
# Seq2seq_model(
#   (encoder_net): EncoderLSTM(
#     (dropout): Dropout(p=0.5, inplace=False)
#     (embbed_layer): Embedding(19757, 400)
#     (lstm): LSTM(400, 512, dropout=0.5)
#   )
#   (decoder_net): DecoderLSTM(
#     (dropout): Dropout(p=0.5, inplace=False)
#     (embbed_layer): Embedding(14747, 400)
#     (lstm): LSTM(400, 512, dropout=0.5)
#     (fc): Linear(in_features=512, out_features=14747, bias=True)
#   )
# )

# %%
joblib.dump(model, '/content/drive/MyDrive/Temp/Hindi3/Model/model.joblib')
pickle.dump(model, open('/content/drive/MyDrive/Temp/Hindi3/Model/model.pkl', 'wb'))

# %% [markdown]
# ## Setting the training of model

# %% [markdown]
# **Note:** To train the model again, please set train_model=True

# %%
batch_size=64
optimizer=optim.Adagrad(model.parameters(),lr=0.005)  #slowed down the learning rate to better convergence
PATH="/content/drive/MyDrive/Temp/Hindi3/phase2_v2.pth"

#model was trained for 90 epochs but due to session length limit it was trained in 3 steps of 30 epochs each
epochs=30
epoch_loss=0.0
padding_idx=eng_lang.word_to_index["<PAD>"]
criterion=nn.CrossEntropyLoss(ignore_index=padding_idx) #ignore padding index while calculating loss

train_model=True #if need to train the model again, set it to True
model_available=False

if train_model==False:
    model=torch.load(PATH)
else:
    if model_available:
        model=torch.load(PATH)
    batches=len(pairs)//batch_size
    for epoch in range(epochs):
        print(f"epoch {epoch+1}/{epochs}")
        model.eval()
        model.train(True)
        cur_batch=0
        for idx in range(0,len(pairs),batch_size):
            cur_batch+=1
            if(cur_batch%100==0):
                print(f"    running batch {cur_batch} of {batches}")
            if idx+batch_size < len(pairs):
                src_batch=hin_tensors[idx:idx+batch_size]
                target_batch=eng_tensors[idx:idx+batch_size]
            else:
                src_batch=hin_tensors[idx:]
                target_batch=eng_tensors[idx:]

            src_batch=torch.cat(src_batch,dim=1)     #max_len*batch_size
            target_batch=torch.cat(target_batch,dim=1)

            output=model(src_batch,target_batch)
            output=output[1:].reshape(-1,output.shape[2])
            target=target_batch[1:].reshape(-1)

            optimizer.zero_grad()
            loss=criterion(output,target)

            loss.backward()
            # restrict gradients from exploding
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1)

            optimizer.step()
            epoch_loss += loss.item()

        print(f"Epoch loss : {loss.item()}")

        torch.save(model,PATH)
        model_available=True
# Out:
# epoch 1/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 5.173855304718018
# epoch 2/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 4.801079273223877
# epoch 3/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 4.593860149383545
# epoch 4/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 4.494425296783447
# epoch 5/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 4.462131023406982
# epoch 6/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 4.407496452331543
# epoch 7/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 4.310941696166992
# epoch 8/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 4.113631725311279
# epoch 9/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 4.179290771484375
# epoch 10/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 4.153500556945801
# epoch 11/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 4.0459303855896
# epoch 12/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.953184127807617
# epoch 13/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.9277167320251465
# epoch 14/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.979849338531494
# epoch 15/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.8915553092956543
# epoch 16/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.8845062255859375
# epoch 17/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.6777422428131104
# epoch 18/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.5704760551452637
# epoch 19/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.9390172958374023
# epoch 20/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.580974817276001
# epoch 21/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.9512901306152344
# epoch 22/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.6886773109436035
# epoch 23/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.5460565090179443
# epoch 24/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.9534764289855957
# epoch 25/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.5660345554351807
# epoch 26/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.5038652420043945
# epoch 27/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.589519500732422
# epoch 28/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.3167731761932373
# epoch 29/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.8114869594573975
# epoch 30/30
#     running batch 100 of 854
#     running batch 200 of 854
#     running batch 300 of 854
#     running batch 400 of 854
#     running batch 500 of 854
#     running batch 600 of 854
#     running batch 700 of 854
#     running batch 800 of 854
# Epoch loss : 3.710545778274536

# %% [markdown]
# Checking translation of 50 sentences from the training set.

# %%
test_sentences=[pair[0] for pair in pairs[50:100]]
actual_sentences=[pair[1] for pair in pairs[50:100]]
pred_sentences=[]

for idx,i in enumerate(test_sentences):
    # print(i)
    translated=predict_translation(model,i,device)
    print("*"*20)
    print(f"Hindi: {i}")
    print(f"Actual: {actual_sentences[idx]}")
    print(f"Predicted: {translated}")
    print("*"*20)

# %% [markdown]
# # Generating Validation Set results

# %%
import string
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import numpy as np
import pandas as pd

import random
import joblib
import pickle
device = torch.device("cpu")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
### Encoder RNN Implementation
class EncoderLSTM(nn.Module):
    def __init__(self,size_input,size_embbeding,size_hidden,layers,p):
        super(EncoderLSTM,self).__init__()
        self.size_input=size_input
        self.size_embbeding=size_embbeding
        self.size_hidden=size_hidden
        self.layers=layers
        self.dropout=nn.Dropout(p)
        self.tag=True

        self.embbed_layer=nn.Embedding(self.size_input,self.size_embbeding)
        self.lstm=nn.LSTM(self.size_embbeding,self.size_hidden,self.layers,dropout=p)

    def forward(self, x):
        # print(x.shape)
        embbeding=self.dropout(self.embbed_layer(x))
        # print(embbeding.shape)
        output, (hidden_st,cell_st) = self.lstm(embbeding)
        return hidden_st, cell_st # will return only hidden and cell state from the Encoder

# %%
### Decoder RNN Implementation
class DecoderLSTM(nn.Module):
    def __init__(self,size_input,size_embbeding,size_hidden,layers,p,size_output):
        super(DecoderLSTM,self).__init__()
        self.size_input=size_input
        self.size_embbeding=size_embbeding
        self.size_hidden=size_hidden
        self.layers=layers
        self.size_output=size_output
        self.dropout=nn.Dropout(p)
        # self.tag=True

        self.embbed_layer=nn.Embedding(self.size_input,self.size_embbeding) # input_size X embedding_size
        self.lstm=nn.LSTM(self.size_embbeding,self.size_hidden,self.layers,dropout=p) #embedding_size * hidden_size
        self.fc=nn.Linear(self.size_hidden,self.size_output) # hidden_size*output_size

    def forward(self,x,hidden_st,cell_st):
        x=x.unsqueeze(0)
        embbeding=self.dropout(self.embbed_layer(x))
        outputs, (hidden_st, cell_st) = self.lstm(embbeding, (hidden_st,cell_st))
        preds=self.fc(outputs)
        preds=preds.squeeze(0)
        return preds,hidden_st,cell_st

# %%
class Seq2seq_model(nn.Module):
    def __init__(self,encoder_net,decoder_net):
        super(Seq2seq_model,self).__init__()
        self.encoder_net=encoder_net
        self.decoder_net=decoder_net

    def forward(self,src,target,teacher_forcing=0.5):
        batch_length=src.shape[1]
        target_len=target.shape[0]
        target_vocab_len=eng_lang.num_of_words

        output_tensor=torch.zeros(target_len,batch_length,target_vocab_len).to(device)
        hidden_st_enc, cell_st_enc=self.encoder_net(src)
        x=target[0]

        for i in range(1,target_len):
            output,hidden_st_dec,cell_st_dec=self.decoder_net(x,hidden_st_enc,cell_st_enc)
            output_tensor[i]=output
            pred=output.argmax(1)
            x=target[i] if random.random()<teacher_forcing else pred #teacher forcing is used with probability 0.5

        return output_tensor

# %%
SOS_token=0
EOS_token=1
PAD_token=2
MAX_LENGTH=10
def clean_sentence(sentence):
    punctuations=list(string.punctuation)
    cleaned=""
    for letter in sentence:
        if letter=='<' or letter=='>' or letter not in punctuations:
            cleaned+=letter
    return cleaned

def predict_translation(model,sentence,device,max_length=MAX_LENGTH):
    sentence=clean_sentence(sentence)
    tokens=sentence.split(" ")
    indexes=[]
    for token in tokens:
        if token in hindi_lang.word_to_index:
            indexes.append(hindi_lang.word_to_index[token])
        else:
            indexes.append(hindi_lang.word_to_index["<UKN>"])
    tensor_of_sentence=torch.LongTensor(indexes).unsqueeze(1).to(device)
    with torch.no_grad():
        hidden,cell=model.encoder_net(tensor_of_sentence)
    outputs=[SOS_token]
    for _ in range(max_length):
        prev_word=torch.LongTensor([outputs[-1]]).to(device)
        with torch.no_grad():
            output,hidden,cell=model.decoder_net(prev_word, hidden,cell)
            pred=output.argmax(1).item()

        outputs.append(pred)

        if eng_lang.index_to_word[pred] =="<EOS>":
            break

    final=[]

    for i in outputs:
        if i == "<PAD>":
            break
        final.append(i)

    final = [eng_lang.index_to_word[idx] for idx in final]
    translated=" ".join(final)
    return translated

# %%
model=joblib.load('/content/drive/MyDrive/Temp/Hindi3/Model/model.joblib')

# %%
model=torch.load("/content/drive/MyDrive/Temp/Hindi3/phase2_v2.pth")

# %%
#model = pickle.load(open('/content/drive/MyDrive/Temp/Hindi3/Model/model.pkl', 'rb'))
#eng_lang = pickle.load(open('/content/drive/MyDrive/Temp/Hindi3/Model/eng_lang.pkl', 'rb'))
#hindi_lang = pickle.load(open('/content/drive/MyDrive/Temp/Hindi3/Model/hindi_lang.pkl', 'rb'))

# %%
# We need to create dictionaries for both Hindi and English languages. We will also assign
# indexes to all the words in vocabulary.
SOS_token=0
EOS_token=1
PAD_token=2
MAX_LENGTH=10

class Vocab_class:
    def __init__(self):
        self.word_to_index={"<SOS>":0,"<EOS>":1,"<PAD>":2,"<UKN>":3}  #dict to map each token to an index
        self.word_counts={} # will keep track of each token in the vocabulary
        self.index_to_word={0:"<SOS>", 1:"<EOS>", 2:"<PAD>", 3:"<UKN>"} # will map each index to a token
        self.num_of_words=4

    def sentence_add(self, sentence): # function to add the words of a sentence into the vocabulary
        words=sentence.split(" ")
        for word in words:
            if word not in self.word_to_index:
                self.word_to_index[word]=self.num_of_words
                self.word_counts[word]=1

                self.index_to_word[self.num_of_words]=word
                self.num_of_words+=1
            else:
                self.word_counts[word]+=1

# %%
hindi_lang=joblib.load('/content/drive/MyDrive/Temp/Hindi3/Model/hindi_lang.joblib')
eng_lang=joblib.load('/content/drive/MyDrive/Temp/Hindi3/Model/eng_lang.joblib')
val_data=pd.read_csv("/content/drive/MyDrive/Temp/Hindi3/test-statements-phase2.csv")
val_data.head()
sentences=val_data['hindi']
sentences=sentences.apply(lambda x : x.strip())
#sentences=["i just want to be your highness head on"]
fp=open("/content/drive/MyDrive/Temp/Hindi3/answer_week2_v11.txt","w")

# %%
count=1
sentence_list=[]
translated_list=[]
for sentence in sentences:
    translated=predict_translation(model,sentence,device)
    translated=translated.split(" ")[1:-1]
    translated=" ".join(translated)
    fp.write(translated+'\n')
    sentence_list.append(sentence)
    translated_list.append(translated)
    print("sentence   : "+sentence)
    print("translated : "+translated)
    print(f"sentence : {count}")
    count+=1
fp.close()

# %%
valdata=data.tail(3000)
valdata.head()
# Out:
#                                                    hindi  \
# 99320                     लगभग एक snuggie के लिए कहता है
# 99321        हम सुरक्षा और गबन के रखरखाव के लिए यहाँ हैं
# 99322  और ऐसा इसलिए नहीं है कि मैं उस विद्यार्थी से ब...
# 99323  ये एक अद्भुत आकृति है लेकिन हमारे पास उतने आंक...
# 99324  और वाकई बहुत से लोगों के दिल में यह बात घर कर ...
#
#                                                  english  len_hindi  \
# 99320                         almost calls for a snuggie          7
# 99321       were here for security and drone maintenance         10
# 99322  this is not because i am a better person than ...         30
# 99323  so theres an interesting pattern but we dont h...         20
# 99324  and certainly lots of people have taken to hea...         24
#
#        len_english  is_mixed
# 99320            5      True
# 99321            7     False
# 99322           26     False
# 99323           17     False
# 99324           19     False

# %%
sentences_hi=valdata['hindi']
sentences_en=valdata['english']

# %%
sentences_en.head()
# Out:
# 99320                           almost calls for a snuggie
# 99321         were here for security and drone maintenance
# 99322    this is not because i am a better person than ...
# 99323    so theres an interesting pattern but we dont h...
# 99324    and certainly lots of people have taken to hea...
# Name: english, dtype: object

# %%
import itertools
count=1
sentence_en_list=[]
translated_list=[]
for (sentence, sentence_en) in itertools.zip_longest(sentences_hi, sentences_en):
#for sentence in sentences_hi:
    translated=predict_translation(model,sentence,device)
    translated=translated.split(" ")[1:-1]
    translated=" ".join(translated)
    #fp.write(translated+'\n')
    sentence_en_list.append(sentence_en)
    translated_list.append(translated)
    print("sentence   : "+sentence)
    print("translated : "+translated)
    print("sentence_en : "+sentence_en)
    print(f"sentence : {count}")
    count+=1
fp.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# sentence   : गोराबाल
# translated : greg they dont want want to see you know
# sentence_en : blond hair
# sentence : 1751
# sentence   : आप इससे सहमत हैं
# translated : youre gonna get rid hes not gonna be a
# sentence_en : so you agree with that
# sentence : 1752
# sentence   : और फिर भी प्रति व्यक्ति मांस की खपत पूरे इतिहास में सबसे ज्यादा है ।
# translated : and there is there is not gonna be careful
# sentence_en : and yet per capita meat consumption is as high as its been in recorded history
# sentence : 1753
# sentence   : मेरे दर्शन का तीसरा पहलू हैं आगे बढ़ते रहना
# translated : they are you know the other
# sentence_en : the third aspect to the philosophy is keep moving forward
# sentence : 1754
# sentence   : आपकी 08 00 अपने रास्ते पर है
# translated : hes so not just gonna take care of course
# sentence_en : your 800 am is on his way up
# sentence : 1755
# sentence   : ऐ
# translated : laughter he didnt mean must be careful a lot
# sentence_en : whoa hey
# sentence : 1756
# sentence   : हंसी मुझे लगा मतलब क्या है इसका
# translated : what i did they dont want it was a
# sentence_en : laughter i was like what does that mean
# sentence : 1757
# sentence   : अलविदा dr brand
# translated : laughter he didnt want to go ahead to dnitz
# sentence_en : goodbye dr brand
# sentence : 1758
# sentence   : आप हथियार की जरूरत है मैं और मलेशियाई सरकार के समर्थन की व्यवस्था करना चाहिए
# translated : i need to be the sea
# sentence_en : you must arrange the weapons i need and malaysian govts support
# sentence : 1759
# sentence   : और अगर आप कार्यालय में नहीं आया था जब
# translated : and you dont want want to find him the
# sentence_en : and when you didnt come to the office
# sentence : 1760
# sentence   : तुम क्या कहते हो
# translated : what are you know the other
# sentence_en : what do you say to that
# sentence : 1761
# sentence   : यह उसको एक नृत्यरचनाकार के रूप में मज़ेदार और नई चीज़ें करने में सक्षम करती है क्योंकि उसने उसको दर्शाया है।
# translated : and i have have a good
# sentence_en : that enables him as a choreographer to do cool stuff to do new things because he has represented it
# sentence : 1762
# sentence   : यह एक पूरी अलग स्तर है
# translated : heres the car
# sentence_en : this is a whole different level
# sentence : 1763
# sentence   :  ठीक है ठीक है
# translated : okay so heres the hell is going to go
# sentence_en :  okay okay
# sentence : 1764
# sentence   : खलिहान दरवाजा खुला है
# translated : hes so heres the president
# sentence_en : barn doors open
# sentence : 1765
# sentence   : मैं भी  huh
# translated : laughter and then i will take care of course
# sentence_en : even me huh
# sentence : 1766
# sentence   : इसे नीचे रखो
# translated : laughter he must be careful back to be careful
# sentence_en : put it down
# sentence : 1767
# sentence   : अगर आपको अपने बर्थडे केक पर छपाई चाहिये तो आपको हमारे पास पहले से उपलब्ध चित्रों में से एक लेना होगा  केवल पेशेवर कलाकारों द्वारा बनाये गये चित्रों से।
# translated : you can go get rid to withstand bed father
# sentence_en : if you want a printed sugar birthday cake you have to use one of our prefab images  only for professionals
# sentence : 1768
# sentence   :  ऐसा सोचना था फिट्ज़पैट्रिक को काम सौंपने से पहले बेवकूफ़ गधे।
# translated : they can be a lot of course course he
# sentence_en : you should have thought about that before you put fitzpatrick in charge you stupid prick
# sentence : 1769
# sentence   : मैं आगे बढ़ रहा है
# translated : hes hes just trying not gonna get get rid
# sentence_en : im moving
# sentence : 1770
# sentence   : विश्वविद्यालय परिसर के मुख्य भवन के पास जाओ।
# translated : lets go go home
# sentence_en : go to the main building of the university campus
# sentence : 1771
# sentence   : सावधान।
# translated : laughter he must cant just have a lot of
# sentence_en : careful
# sentence : 1772
# sentence   : तो मुझे लगता है कि एक पल सोचने के लिए चाहिए और मैं इससे कुछ बनाने की कोशिश करूंगी। संगीत
# translated : i would be be a few
# sentence_en : so im going to have a moment to think and ill try to make something out of it
# sentence : 1773
# sentence   : हां
# translated : laughter so heres the trident hell be pregnant so
# sentence_en : yes
# sentence : 1774
# sentence   : यह 400 साल पुराना है।
# translated : heres the worst just like a little bit lesbian
# sentence_en : the age is 400 years
# sentence : 1775
# sentence   : क्या ये तुम हो
# translated : what are you know the hell are not gonna
# sentence_en : is it you
# sentence : 1776
# sentence   : और मैं बता सकता था कि मेरी क्षमा से वह बदल गया था।
# translated : i was my wife was my husband broker what
# sentence_en : and i could tell that my hand of forgiveness had changed him
# sentence : 1777
# sentence   : उन्होंने हुक करने के लिए चाहते थे कि देश के परमाणु शस्त्रागार घंटेकालटकन
# translated : they want to go ahead to go ahead to
# sentence_en : he wanted to hook up the nations nuclear arsenal to the clapper
# sentence : 1778
# sentence   : लगभग दस लाख से दस करोड़ के बीच कहीं मृतकों की सँख्या होगी या तो वायरस के कारण या चिकित्सा प्रणालियों के पतन के कारण।
# translated : or or i was just have a lot of
# sentence_en : somewhere in the range of millions to hundreds of millions of people die either from the virus or the collapse of health care systems
# sentence : 1779
# sentence   : सामान्य संपर्क करने जैसे कि जकड़ने चुंबन लेने या एक साथ खाने या खाना पकाने के बर्तनों से एचसीवी hcv नहीं फैलता है
# translated : or or not a few
# sentence_en : hcv is not spread through casual contact such as hugging kissing or sharing eating or cooking utensils
# sentence : 1780
# sentence   : will my grandma keep quiet if my vermillion is erased
# translated : she sinks i was just need a lot of
# sentence_en : will my grandma keep quiet if my vermillion is erased
# sentence : 1781
# sentence   : आज मैं एक अच्छे मूड में हूँ
# translated : im sorry a good morning girl mr wells president
# sentence_en : today im in a good mood
# sentence : 1782
# sentence   : आप अपमानित मिल जाएगा मैं क्या परवाह है।
# translated : what if you know what happens in the worst
# sentence_en : you will get humiliated what do i care
# sentence : 1783
# sentence   : बड़ा नजरिया रखने का संबंध दूसरे विकल्प से है और इसका चयन करने से है भले यह कितना ही कठिन हो आपको कितनी ही गहरी चोट क्यों न लगी हो आगे बढ़ने के विकल्प का चुनाव करना भविष्य की ओर नन्हा कदम बढाने जैसा ही है
# translated : ive got some money in the worst good morning
# sentence_en : having a great attitude is about choosing option number two and choosing no matter how difficult it is no matter what pain hits you choosing to move forward and move on and take baby steps into the future
# sentence : 1784
# sentence   : एक हॉट चॉकलेट हो रही तरह लग रहा है
# translated : hes looks like my wife life is tonedeaf like
# sentence_en : feel like getting a hot chocolate
# sentence : 1785
# sentence   : वे थोड़े बड़े हैं
# translated : theyre theyve could be considerable on the car
# sentence_en : theyre a bit big
# sentence : 1786
# sentence   : क्या दो दिमाग पर निर्भर होता है यह कौन है।
# translated : its is a lot of course the worst fuck
# sentence_en : two brains eh it depends on who it is
# sentence : 1787
# sentence   : खैर मेरी शुभकामनाएँ।
# translated : heres the hell the other was gonna have a
# sentence_en : well good luck to you
# sentence : 1788
# sentence   : कभीकभी सुधार किए गए थे  यहां तक कि स्फिंक्स को नौकरी मिल गई।
# translated : he must have taken had to withstand upload shouldve
# sentence_en : sometimes improvements were made  even the sphinx got a nose job
# sentence : 1789
# sentence   : और आखिर चीनी सरकार उन पर टूट पडी
# translated : they they were gonna be careful
# sentence_en : and finally the chinese cracked down
# sentence : 1790
# sentence   : आप मुश्किल से भाग निकले।
# translated : howd you got a lot of course course i
# sentence_en : you barely escaped
# sentence : 1791
# sentence   : तुम बस उसके कंट्रोलर को reset कर दो
# translated : ill give you get it was gonna get rid
# sentence_en : just reset the controllers
# sentence : 1792
# sentence   :
# translated : greg tz then he must be punished made a
# sentence_en : huh
# sentence : 1793
# sentence   : इन मातापिता को भारी अपराधबोध महसूस होता है लेकिन फिर आक्रोश और फिर अधिक अपराध बोध।
# translated : and then i just want to be a lot
# sentence_en : these parents feel enormous guilt but then resentment and then more guilt
# sentence : 1794
# sentence   : मुझे मेरी चित्रकला की प्रदर्शनी का मौका भी मिला मैंने अपने रंग जहाज से भेजे और महाबलीपुरम पहुँची
# translated : i i want want to me the breach
# sentence_en : promising to give exhibitions of paintings i shipped my paints and arrived in mahabalipuram
# sentence : 1795
# sentence   : यह रचना प्रेरित है उस कठिन परिश्रम से जो महिला और पुरुष जेल के भीतर करते हैं ताकि आने वाले वक़्त में अपनी ज़िन्दगी बेहतर बना सकें जब वे अपनी सज़ा पूरी कर लें।
# translated : you can go back to sleep stay here be
# sentence_en : this piece is inspired by all of the hard work that men and women are doing on the inside to create better lives and futures for themselves after they serve their time
# sentence : 1796
# sentence   : दुश्मन के द्वार  नीचे है
# translated : laughter and thats why dont know what did not
# sentence_en : the enemys gate is down
# sentence : 1797
# sentence   : मेरे देश के पश्चिमी तट तक साल की ज्यादातर भाग मेँ आप ज्यादा वनस्पति विकास नही देख सकते।
# translated : but you you see you think they dont want
# sentence_en : up the west coast of my country for much of the year you dont see much vegetation growth
# sentence : 1798
# sentence   : उनमें से एक सन्देश में लिखा था मुझे लगता है की तुमने मेरी नन्ही भतीजी मासा को बचाया है।
# translated : i could i said
# sentence_en : one of those messages said i believe you saved my little niece masa
# sentence : 1799
# sentence   : दोस्तों अपनी आँखें खुली रखो
# translated : they could have a lot of course course not
# sentence_en : guys keep your eyes open
# sentence : 1800
# sentence   : आप दो कि तिजोरी से बाहर आता है कि कुछ भी मार
# translated : you you got some of course course i think
# sentence_en : you two kill anything that comes out of that vault
# sentence : 1801
# sentence   : तुम जानते हो
# translated : how do you know what are you know the
# sentence_en : you do too know
# sentence : 1802
# sentence   : ताली लग भग
# translated : laughter and they dont want want to find the
# sentence_en : applause roughly
# sentence : 1803
# sentence   : jinwol क्षेत्र में समुद्री डाकू एकीकृत हो एक दर्जन से अधिक छोटे समुद्री डाकू गिरोह और प्रमुख शक्ति बनने
# translated : and then i will be a lot of course
# sentence_en : pirates in the jinwol area have unified a dozen smaller pirate gangs and become the dominant power
# sentence : 1804
# sentence   : जलस्तर 300 फ़ीट 100 मीटर नीचे है।
# translated : heres the car
# sentence_en : the groundwater is 300 feet deep 100 meters
# sentence : 1805
# sentence   : आप देखिए मेरे 30 से अधिक चचेरे भाई हैं लेकिन मैं हसन नाम का कोई नहीं जानता था।
# translated : i dont have a lot of course course i
# sentence_en : you see i have well over 30 first cousins but i didnt know anybody named hassen
# sentence : 1806
# sentence   : किन्नर होना अजीब है क्योंकि हर कोई अजीब हो जाता है जब वे मेरे आसपास होते हैं।
# translated : theyre they dont want want to be the hell
# sentence_en : being trans is awkward because everyone else gets awkward when theyre around me
# sentence : 1807
# sentence   : ये ज्यादा से ज्यादा एक तरीका है आयोजन के लिए एक माहौल बनाने का और समूहों को सहायता देने के लिए
# translated : i will be a good night
# sentence_en : it is more and more often a way of creating an environment for convening and supporting groups
# sentence : 1808
# sentence   : इस नई योजना को परिक्षण करने के लिए हमने एक छोटा dune buggy वाहन का प्रतिरूप बनाया ऐसे वाहन की संभावना परखने के लिए
# translated : i think have to be robb be a lot
# sentence_en : so to test this crazy idea we developed a small dune buggy prototype vehicle to test the feasibility
# sentence : 1809
# sentence   : मैं आपसे बाद में बात करेंगे
# translated : ill tell you should be a lot of course
# sentence_en : ill talk to you later
# sentence : 1810
# sentence   : मैं बेहद संवेदनशील थी लेकिन जब तक मैं पूरी किशोर हुई मैं बिल्कुल सुन्न थी।
# translated : i i was just wanted to see you know
# sentence_en : i was extremely sensitive but by the time i was an adolescent i had numbed out
# sentence : 1811
# sentence   : मैं आप को रोकने के लिए जा रहा हूँ
# translated : im gonna gonna be the hell is going to
# sentence_en : im going to stop you
# sentence : 1812
# sentence   : आप कैसे लग देखें
# translated : how how many many about her name is not
# sentence_en : see how you look
# sentence : 1813
# sentence   : विभिन्न नौकरियों विभिन्न कारों
# translated : laughter he must be careful be careful really have
# sentence_en : different jobs different cars
# sentence : 1814
# sentence   : एक एम्बुलेंस आई मैं पूरे होश में थी। और वैज्ञानिक होने के नाते मैंने सफ़र में हर चीज़ का विश्लेषण किया सड़क पर चलती गाड़ियों की आवाज़ें गुज़रती हुई गलियों की लाइटें और फिर शहर की गलियों की लाइटें।
# translated : i i need your mother your mother mother like
# sentence_en : an ambulance came i was still fully conscious and i analyzed everything on the journey because im a scientist the sound of the tires on the road the frequency of the street lights and eventually the city street lights
# sentence : 1815
# sentence   : आप देखते हैं कि
# translated : howd thats why did he was just gonna be
# sentence_en : you see that
# sentence : 1816
# sentence   : ग्यारह
# translated : they dont want to be a lot of course
# sentence_en : eleven
# sentence : 1817
# sentence   :  नहीं तुम नहीं करोगे
# translated : no hes not gonna get rid out of course
# sentence_en :  no you wont
# sentence : 1818
# sentence   : कौन है
# translated : hes so heres the hell is leibnizs gonna get
# sentence_en : who is that
# sentence : 1819
# sentence   : गुड लक ब्रूक्स
# translated : she was just must have a lot of course
# sentence_en : good luck brooks
# sentence : 1820
# sentence   : और अब सिर्फ देखने के बजाय कि बिल्ली और कुत्ते हम उन्हें चारों ओर घूमते देख सकते हैं और एक दूसरे के साथ बातचीत करते हुए।
# translated : and when i can go
# sentence_en : and now instead of just seeing that cat and dog we can see them move around and interact with each other
# sentence : 1821
# sentence   : सो हमारे पास ये रहस्यमयी शीर्षक है जिसका कोई भावार्थ नहीं है तो मैं सोचने की कोशिश कर रहा था कि मैं कहाँ रहस्यमयी पाठ्य देख सकता हूँ जिसका भावार्थ लगे पर हो ना
# translated : i cant go go back
# sentence_en : so youve got this mysterious title that really doesnt mean anything so i was trying to think where might i see a bit of mysterious text that seems to mean something but doesnt
# sentence : 1822
# sentence   : नहींहै मैंइसकेलिएइतनीमेहनत काम किया है
# translated : hes so heres the hell is going to go
# sentence_en : not when ive worked so hard for it
# sentence : 1823
# sentence   : हमें कुछ करना है
# translated : hes just gonna get rid not gonna get rid
# sentence_en : we have to do something
# sentence : 1824
# sentence   : नहीं मैंने नहीं
# translated : no they dont want want to be careful careful
# sentence_en : no i didnt
# sentence : 1825
# sentence   : इस समय यह कल्पना करना मुश्किल है कि आपके प्यारे बच्चे अपने ख़ून से सने न पड़े हों।
# translated : you put your son
# sentence_en : its probably er hard at this point not to picture your precious offspring lying in a pool of their own blood
# sentence : 1826
# sentence   : और अच्छी चीजें कभी मरती नहीं
# translated : laughter he didnt want want to leave me introduce
# sentence_en : and no good thing ever dies
# sentence : 1827
# sentence   : 23 साल के भीतर
# translated : laughter applause then they must have a lot of
# sentence_en : within 23 years
# sentence : 1828
# sentence   : समझी
# translated : laughter he must be be a lot of course
# sentence_en : i see
# sentence : 1829
# sentence   : मैं आप की सबसे अच्छा प्रदर्शन कर रहे हैं कि देखने के िलए खुश हूँ जैसा कि आप जानते   कमान स्कूल के िलए प्रतियोगिता कठिन है
# translated : youre youre not gonna be a lot of course
# sentence_en : im pleased to see that most of you are performing well as you know competition for command school is tough some in the higher ranks have failed to meet our standards and are being sent home
# sentence : 1830
# sentence   : 2000 में अगर आपने कहा होता कि उच्च गुणवत्ता वाले सेलुलर नेटवर्क लगभग आनेवाले थे पूरे अफ्रीका में लोगों ने आपको पागल कहा होता।
# translated : i said think just want to see him down
# sentence_en : in 2000 if you had said that highquality cellular networks were about to roll out across all of africa people would have told you that you were crazy
# sentence : 1831
# sentence   : कोबराकमांडर
# translated : theoretically but hes tripling your daggers chance of course
# sentence_en : cobra commander
# sentence : 1832
# sentence   : लेकिन उसी समय संलग्न संभावनाओं का यह एक संपूर्ण ब्रह्मांड है।
# translated : its a lot of course he was hugely my
# sentence_en : but at the same time it has a whole universe of possibilities attached
# sentence : 1833
# sentence   :  पेट्रा आरोपी
# translated : greg heres they speared that was a lot of
# sentence_en :  charged petra
# sentence : 1834
# sentence   : खैर मुझे लगता है कि हम यहाँ किया
# translated : well i think we did he didnt have been
# sentence_en : well i guess were done here
# sentence : 1835
# sentence   :  उसे बुलाइए
# translated : tz so sorry i was just got a lot
# sentence_en : call him
# sentence : 1836
# sentence   : और वो भी तब जब आप अदृश्य पदार्थ को देख पाते
# translated : and when they did he was just want to
# sentence_en : and if you could see invisible matter too
# sentence : 1837
# sentence   : और इनका उपयोग नहीं किया जाता है बोनस के लिए या प्रचार के लिए।
# translated : they dont want to see you know what happened
# sentence_en : and these are not used for bonuses or for promotions
# sentence : 1838
# sentence   :  बिल्कुल नहीं
# translated : hes not just a lot of course course he
# sentence_en :  no of course not
# sentence : 1839
# sentence   : धीमी अस्पष्ट छनछनाहट
# translated : laughter applause hes just got a lot lot of
# sentence_en : chiming faintly
# sentence : 1840
# sentence   : और अगर हाल ही में जब तक आप मंगल ग्रह पर नहीं रहे हो आपको पता है कि वहाँ इस तरह की बहुत बातें हैं ।
# translated : you know the best
# sentence_en : and unless youve been on mars recently you know theres a lot of that out there
# sentence : 1841
# sentence   :  कि वे हम से क्या चाहते है
# translated : they want to go ahead on the phone night
# sentence_en :  thats what they want from us
# sentence : 1842
# sentence   : भगवान यह चमत्कार है
# translated : hes so sorry the same
# sentence_en : lord its a miracle
# sentence : 1843
# sentence   : मैंपीछेछूटगई मुझे पार ले चल नाविक
# translated : i just want to kill him me down anything
# sentence_en : i am left behind row me across to the other side
# sentence : 1844
# sentence   : यह अजीब है  है हाँ
# translated : its not just gonna get get rid to see
# sentence_en : its weird yeah
# sentence : 1845
# sentence   : आगे आओ
# translated : lets go ahead then hell did not even gonna
# sentence_en : come forth
# sentence : 1846
# sentence   : कहानियों की अपनी महत्ता होती है। एक मानवविज्ञानी होने के नाते मैं जानता हूँ।
# translated : im not gonna be a little bit bit bit
# sentence_en : stories matter as an anthropologist i know that
# sentence : 1847
# sentence   : आप लोगों की प्रतिक्रिया जान कर आश्चर्य चकित होंगे
# translated : you can be done in the basement
# sentence_en : you might wonder how people reacted to this
# sentence : 1848
# sentence   : आप में से कोई भी इस महान भाग्य विनाश करने के लिए हम सभी को ड्राइव कर सकते हैं कि डर लगता है
# translated : you can see that can see you think they
# sentence_en : none of you fear that this great fortune may drive us all to destruction
# sentence : 1849
# sentence   : माइकल ब्राउन कि मौत और समुदाय का उपचार फ़र्गुसन और सेंट लुइस मे विरोध प्रदर्शन का कारण बना
# translated : they need more
# sentence_en : michael browns death and the subsequent treatment of the community led to a string of protests in and around ferguson and st louis
# sentence : 1850
# sentence   : विशेष रूप से हम जानना चाहते हैं कैसे serotonin प्रभावित करता है जब लोगों के साथ गलत तरीके से बर्ताव होता है
# translated : how many many people know what happened about our
# sentence_en : specifically we wanted to know how serotonin would affect the way people react when theyre treated unfairly
# sentence : 1851
# sentence   : कीबोर्ड clacking
# translated : laughter he was just never must have been been
# sentence_en : keyboard clacking
# sentence : 1852
# sentence   : गुलाब के सुंदर से फूल पर मेरी आँखें चिपक ही गयी मेरे बचपन के परिदृश्य में जैसे खिल रही हो।
# translated : but i dont know what if youre gonna be
# sentence_en : my eyes became glued to the patterns of embroidered roses blooming across my childhood landscape
# sentence : 1853
# sentence   : अस्पताल में विजिटर्स का आना मना था इसलिए मेरी मां ने अस्पताल के एक कर्मचारी को रिश्वत दी
# translated : he must have a lot of course course he
# sentence_en : there were no visitors allowed so my mother bribed a hospital worker
# sentence : 1854
# sentence   : आइये अब हम कुछ आगे बढ़कर वर्तमान से दस हजार साल पहले चलें
# translated : lets take take care of course them here was
# sentence_en : now lets advance to 10000 years before the present
# sentence : 1855
# sentence   : मैं तुम क्या कर रहे हैं पता उम्मीद है
# translated : what youre youre gonna gonna be a little bit
# sentence_en : i hope you know what youre doing
# sentence : 1856
# sentence   : क्यों आप अपने मेहमानों के मनोरंजन के लिए जाना न  जबकि मैं अपने मेकअप तरोताजा।
# translated : i dont want to go back to be careful
# sentence_en : why dont you go to entertain our guests while i freshen up my makeup
# sentence : 1857
# sentence   : यह मेरी कला है।
# translated : shes my sister world is dickson gonna get rid
# sentence_en : this is my art
# sentence : 1858
# sentence   : मैं उसे मार देना चाहिए
# translated : i should be the fhrer guy
# sentence_en : should i kill him
# sentence : 1859
# sentence   : तुम्हें मदद की ज़रूरत है
# translated : help you need your eyes
# sentence_en : you need help
# sentence : 1860
# sentence   : मुझे कभी भी किताब बना कर किसी प्रदर्शनस्थल को देने की ज़रुरत नहीं पड़ी कि वो निश्चय करें कि मेरा काम लोगों को दिखाने लायक था कि नहीं
# translated : i dont want to be the way
# sentence_en : i would never have to make a book and then present it to a gallery and let them decide if my work was nice enough to show it to people
# sentence : 1861
# sentence   : वह कहां है
# translated : hes so heres the fhrer he was just like
# sentence_en : where is he
# sentence : 1862
# sentence   : मुझे इसे अपने हाथों में लेना होगा
# translated : ill take care of course he didnt want to
# sentence_en : ill have to to take it into my own hands
# sentence : 1863
# sentence   :  मैं तो बची हूँ
# translated : im so sorry sorry sorry about it was a
# sentence_en :  at least it gives me a break
# sentence : 1864
# sentence   : पुरुषों की रक्षा
# translated : fortunately remember how long many cases water
# sentence_en : defend yourselves men till again
# sentence : 1865
# sentence   : रसायन प्लस अपने निजी वस्तुओं
# translated : greg they dont want to go ahead away from
# sentence_en : chemicals plus his personal items
# sentence : 1866
# sentence   : मैने कुछ सहयोगी रोचक कार्यो के माध्यम से सामाजिक संपर्क सीखा था मैने दूसरे बच्चों के साथ ही घोड़ों की सवारी की मैनें दूसरे बच्चों के साथ मिल कर मॉडल रॉकेट बनाए है दूसरे बच्चों के साथ इलेक्ट्रॉनिक्स प्रयोगशाला मे काम किया था
# translated : good good time good time time good luck anything
# sentence_en : i got social interaction through shared interests  i rode horses with other kids i made model rockets with other kids did electronics lab with other kids
# sentence : 1867
# sentence   : बहनों के लिए इंतजार मत करो
# translated : dont want want to be careful the hell a
# sentence_en : do not wait for the sisters
# sentence : 1868
# sentence   : चलो एरिक
# translated : lets go on your verdict breeding guy
# sentence_en : come on erik
# sentence : 1869
# sentence   : दबी साइमन
# translated : greg howd the hell car
# sentence_en : muffled simon
# sentence : 1870
# sentence   : कुछ लोगों को 10 गुना मेहनत करनी पड़ती है उसी मुकाम तक पहुँचने के लिए क्योंकि बहुत से सामजिक अड़चनें भी आती हैं।
# translated : ive never have been been been a lot of
# sentence_en : some people have to work 10 times as hard to get to the same place due to many barriers put in front of them by society
# sentence : 1871
# sentence   : मैं ने इसके बारे में बहुत सोचा था
# translated : i was really have been included what happened to
# sentence_en : ive thought a lot about it
# sentence : 1872
# sentence   : पर हमें सारी दुनिया में पता चल रहा है बार बार कि अगर आप सिर्फ शौचालय बना कर छोड़ देते हैं तो उसका प्रयोग नहीं होता
# translated : you you cant believe you get rid out of
# sentence_en : but what were finding around the world over and over again is if you build a toilet and you leave it there it doesnt get used
# sentence : 1873
# sentence   : और 500 से ज्यादा ये छोटे पिग्मिस उनके पीछे छुपे हुए हैं
# translated : theyre just want to me get rid of course
# sentence_en : and we had over 500 of these little pygmies hiding behind them
# sentence : 1874
# sentence   : प्लेन स्टूपिड के ज़रिए मुझे ऐसे अभियानों और समुदायों के बहुतसे सम्पर्क सूत्र मिले हैं जो हीथ्रो के आसपास पूर्णतया नष्ट होने के कगार पर थे
# translated : i i was the the hell was going to
# sentence_en : through plane stupid ive had a lot of connections with the campaign and communities around heathrow that were facing complete destruction
# sentence : 1875
# sentence   :  कार
# translated : jung hes just trying gonna get rid of course
# sentence_en :  car
# sentence : 1876
# sentence   : आखिरकार दिन के अंत में 2 घंटे का यातायात हमें अलग कर देता है
# translated : we can have been been a lot of course
# sentence_en : at the end of the day were separated by something like two hours of heavy traffic
# sentence : 1877
# sentence   : कभीकभार।
# translated : laughter he didnt must be expelled a lot of
# sentence_en :  sometimes
# sentence : 1878
# sentence   : और मुझे विश्वास है कि सही सहयोग के साथ हम इस भयानक बीमारी को हरा देंगे।
# translated : i believe that right here right now
# sentence_en : and i am confident that with the right collaborations we will beat this terrible disease
# sentence : 1879
# sentence   : ठीक है तुम कहाँ जा रहे हो
# translated : where are you were just trying going to go
# sentence_en : well where are you gonna go
# sentence : 1880
# sentence   : वह यहाँ आया और मैं तो उसे पता था सही निशाने पर
# translated : and i i was just got a lot of
# sentence_en : he walked in here and i almost knew him right off the bat
# sentence : 1881
# sentence   : हम सभी कुछ उदाहरण सोच सकते हैं है न
# translated : can can can be a few bit few little
# sentence_en : we can all think of some examples right
# sentence : 1882
# sentence   : हम और बेहतर कर सकते हैं।
# translated : and can do not gonna be be careful up
# sentence_en : we can do better
# sentence : 1883
# sentence   : मैं वापस जैसे ही मैंने यह कर सकते हो जाएगा।
# translated : i can i cant just want to be millionaires
# sentence_en : ill be back as soon as i can
# sentence : 1884
# sentence   : ज़रूर एंडी
# translated : laughter but he didnt want want to go ahead
# sentence_en : sure andy
# sentence : 1885
# sentence   :  नहीं यह पागलपन नहीं है
# translated : no its not a lot of course course not
# sentence_en :  no its not crazy
# sentence : 1886
# sentence   : मार्च के प्रारंभ में दिल्ली के निजामुद्दीन मरकज मस्जिद में होने वाला तबलीगी जमात नामक मजहबी जनसमूह कोरोनवायरस के एक तिव्रप्रसारक घटना के रूप में सामने आया जिसके बाद 900 से अधिक मामलों की पुष्टी हुई तथा देश भर में इस घटना से जुड़े कम से कम 10 लोगों की मौत हो गई। 9000 से अधिक मजहबीप्रचारकों ने जनसमूह में भाग लिया जिनमें से अधिकांश भारत के विभिन्न राज्यों से थे तथा 40 अन्य देशों से 960 लोग उपस्थित थे। 4 अप्रैल तक 17 राज्यों में 1023 मामले तबलीगी जमात महामारी विस्फिटकेन्द्र हॉटस्पॉट से जुड़े हैं जो भारत में पुष्टि किए गए सभी मामलों के 30 का प्रतिनिधित्व करते हैं। तबलीगी जमात के सदस्यों और देश भर में उनके संपर्कों सहित कुल 22000 लोगों को क्वारंटाइन संगरोध में रखा गया है।
# translated : ive seen the world
# sentence_en : as of 3 april more than 950 confirmed cases were detected across 14 states and union territories in the country including 97 percent of the total cases confirmed in the country on 2 and 3 april 647 out of 664 cases
# sentence : 1887
# sentence   : आप बेटा funnin मुझे क्या
# translated : what did you you were trying so sorry many
# sentence_en : are you funnin me son
# sentence : 1888
# sentence   : वानरों ने जंग जीत ली
# translated : tz so sorry sorry about that was gonna be
# sentence_en : apes win war
# sentence : 1889
# sentence   : सही
# translated : laughter he was just need need a lot of
# sentence_en : all right
# sentence : 1890
# sentence   : बहुत से धनवान देशो में भी कुछ ही देशो को पैसे भेजने की अनुमति है
# translated : hes just like it was gonna be careful be
# sentence_en : many rich nations also have a blanket ban on sending money to specific countries
# sentence : 1891
# sentence   : हँसी लेकिन हम वापस आ गए हैं दोबारा पारंपरिक मुद्दे के साथ।
# translated : but they are just not a lot of course
# sentence_en : laughter but we will come back once again to the traditional thing
# sentence : 1892
# sentence   : खैर आप इसे बहुत अच्छा कर रहे हैं
# translated : youre very good good morning time to see you
# sentence_en : well youre pretty good at it
# sentence : 1893
# sentence   : तुम एयरपोर्ट में एक लड़की से मिलोगे
# translated : you just get in the other day in the
# sentence_en : youd meet a girl in airport
# sentence : 1894
# sentence   : अब। एक पांच ब्लॉक परिधि सेट अप
# translated : applause thank you you were gonna get rid out
# sentence_en : set up a fiveblock perimeter
# sentence : 1895
# sentence   : ने सिर चलती
# translated : laughter he drank must be careful be careful easy
# sentence_en : the heads moving
# sentence : 1896
# sentence   : ये वो संख्याएँ हैं जो न्यूयाॅर्क सिटी के बुनियादी ढांचे को बनातीं हैं।
# translated : they cant have a lot of course course he
# sentence_en : these are the numbers that make up the infrastructure of new york city
# sentence : 1897
# sentence   : आप मुझे क्या समझते हो
# translated : what do you know the hell are you think
# sentence_en : who do you think i am
# sentence : 1898
# sentence   : आप ट्रेन सी ब्रॉड स्ट्रीट पर हैं।
# translated : youre are you know what are you know are
# sentence_en : youre on the train c broad street
# sentence : 1899
# sentence   : unnh
# translated : greg and then i want want to be a
# sentence_en : umm
# sentence : 1900
# sentence   : अगर हम मरीज के दिल को प्रभावित कर सकते delay it और वह मर सकते हैं।
# translated : can not can you know what can be a
# sentence_en : if we delayit can affect the patients heart and she can die
# sentence : 1901
# sentence   : मुझे हर रोज़ बहुत सारा प्यार और सकारात्मक संदेश आते हैं।
# translated : i love love
# sentence_en : i get tons of love and press and positive messages daily
# sentence : 1902
# sentence   : ये थे पूरे दिल वाले लोग जो योग्य होने कि गहरी भावना के साथ जी रहे थे।
# translated : he didnt want to go back to be careful
# sentence_en : these are wholehearted people living from this deep sense of worthiness
# sentence : 1903
# sentence   : वह यह तय कर रहा था कि वे अपने संबंधों से कितने संतुष्ट थे
# translated : he was just like your head to replace know
# sentence_en : it was how satisfied they were in their relationships
# sentence : 1904
# sentence   : एक बच्चे के लिए बहुत भारी सोच है है ना
# translated : hes so hes got a lot of course course
# sentence_en : pretty heavy thoughts for a child right
# sentence : 1905
# sentence   :  मुझे यह देखते हैं
# translated : so heres the hell the hell just need a
# sentence_en :  let me see it
# sentence : 1906
# sentence   : यह हार्वर्ड के लिए शिक्षण अस्पताल है  देश के सर्वश्रेष्ठ अस्पतालों में से एक
# translated : hes just like a lot of course course i
# sentence_en : its the teaching hospital for harvard  one of the best hospitals in the country
# sentence : 1907
# sentence   : क्या तुमने अच्छा बर्ताव करने का वादा नहीं किया था
# translated : you you think think about a lot of course
# sentence_en : didnt you promise to behave properly
# sentence : 1908
# sentence   : सात के प्रकाश में वह सब पवित्र और सही है द्वारा
# translated : hes hes not gonna get rid in the the
# sentence_en : in the light of the seven by all that is holy and right
# sentence : 1909
# sentence   : मैं मिया तुमसे प्यार करता हूँ
# translated : love you have two
# sentence_en : i love you mia
# sentence : 1910
# sentence   : इसका मतलब वह छेद कहा है यह याद रख सकता है
# translated : he could remember the hell is not gonna be
# sentence_en : so it could remember where that hole was
# sentence : 1911
# sentence   : इसीलिएइस चित्र में हिमशैल अधिक नीला दिखाई दे रहा है।
# translated : hes so sorry i said the car my fhrer
# sentence_en : thats why the iceberg in this photo looks so blue
# sentence : 1912
# sentence   : तुम उसे हमेशा से जानते हो
# translated : you know him
# sentence_en : youve always known her
# sentence : 1913
# sentence   : इस समय दुनिया के करीब आधे शरणार्थी बच्चे हैं उनमें से कुछ के साथ कोई वयस्क भी होता है एक ऐसी स्थिति जो उन्हें ख़ास तौर पर बाल श्रम या यौन शोषण की चपेट में आसानी से ले सकती है।
# translated : i cant have a few
# sentence_en : today roughly half the worlds refugees are children some of them unaccompanied by an adult a situation that makes them especially vulnerable to child labor or sexual exploitation
# sentence : 1914
# sentence   : अपने डर को जीत  और मैं तुमसे वादा करता हूँ आप मृत्यु पर विजय प्राप्त करेंगे
# translated : i promise you know you know the car car
# sentence_en : conquer your fear and i promise you you will conquer death
# sentence : 1915
# sentence   : अब देखो मैं आप रेगी के बारे में नाराज हो
# translated : now you
# sentence_en : now look i know youre pissed about reggie
# sentence : 1916
# sentence   : हमारी परंपरा में एक शिक्षा जिसे हदीस ख़ुदसी कहते हैं ईश्वर कहते है मेरे सेवक या मेरे जीव मेरे मानव जीव जो मुझे प्यारा है उसके सहारे मेरे पास नहीं आता बल्कि उसके सहारे जो मैंने करने को कहा है
# translated : i dont know what i said didnt have been
# sentence_en : in a teaching  called a hadith qudsi in our tradition  god says that my servant or my creature my human creature does not approach me by anything that is dearer to me than what i have asked them to do
# sentence : 1917
# sentence   : वे आपको धोखा नहीं दे रहे हैं लेकिन कभीकभी वे ऐसा करते हैं।
# translated : dont even know what if you know they must
# sentence_en : your senses show you the world as it is
# sentence : 1918
# sentence   : हम सभी के पास घरों में कंबल हैं और इसके महत्व को समझते हैं।
# translated : we can see the other are you know the
# sentence_en : we all have blankets in our homes and understand the significance that they play
# sentence : 1919
# sentence   : एक एस्प्रेसो मशीन।
# translated : laughter so lets go ahead away from bed
# sentence_en : an espresso machine
# sentence : 1920
# sentence   : कि घड़ी को रीसेट करें
# translated : she could never did you must be punished done
# sentence_en : reset that clock
# sentence : 1921
# sentence   : लेकिन हम सबसे अच्छा हम कर सकते हैं कर दिया गया है हम साथ जाने के रूप में और हम इसे बना रही है तो हो सकता है शायद हमारी सर्वश्रेष्ठ अब काफी अच्छा नहीं है
# translated : we dont have been been not a lot of
# sentence_en : but we have been doing best we can and we have making it up as we go along so maybe maybe our best isnt good enough anymore
# sentence : 1922
# sentence   : यह ठीक है बच्चा है
# translated : thats why is not gonna gonna get rid over
# sentence_en : its okay baby
# sentence : 1923
# sentence   : क्या आप वह अलग है आपको क्यों लगता है
# translated : why do you think think about it was mesmerized
# sentence_en : what makes you think hes different
# sentence : 1924
# sentence   : वॉकर परमाणु हमले की कोशिश कर रहा है।
# translated : hes just trying to be the way
# sentence_en : cale walkers trying to launch a nuclear attack
# sentence : 1925
# sentence   : पर्याप्त मेला
# translated : laughter applause and then he was never have been
# sentence_en : fair enough
# sentence : 1926
# sentence   : मैं तुम्हारे साथ कमबख्त मंजिल मिटा देंगे
# translated : ill see you know the car down
# sentence_en : cause ill wipe the fucking floor with you
# sentence : 1927
# sentence   : बस तेजी से होना है
# translated : hes just trying in the trident but heres your
# sentence_en : just have to be faster
# sentence : 1928
# sentence   : और मै ने देखा उनमेसे से बहुत सारे उदास लग रहे थे
# translated : and i just had a lot of course course
# sentence_en : and i noticed that a lot of them seemed bored
# sentence : 1929
# sentence   : और मैं भी मां हूं  मैं समझती हूँ चिंता की इस भावना को।
# translated : i dont want you want to be careful be
# sentence_en : and im also a parent  i understand this feeling of anxiety
# sentence : 1930
# sentence   : तो अब मैं आपको दिखाना चाहती हूँ की मैं क्या करती रही हूँ।
# translated : what i am i had a few to see
# sentence_en : and so now i want to show you what ive been working on
# sentence : 1931
# sentence   : उसने मेरी शिकायत की।
# translated : laughter he didnt want want to kill him go
# sentence_en : shes reported me
# sentence : 1932
# sentence   : क्या ये रुक जाएगी
# translated : laughter applause applause thank you you must have made
# sentence_en :  will it stop
# sentence : 1933
# sentence   : याबेचनेमैं यह  और पैसे बांट
# translated : laughter applause and then he was just got a
# sentence_en : or sell it and divide the money
# sentence : 1934
# sentence   : सब लोग आ जाओ
# translated : lets go ahead of course course he must never
# sentence_en : come on everybody
# sentence : 1935
# sentence   : कौन इस आधुनिक युग में सपनों में विश्वास रखता है
# translated : actually really really have to see you know what
# sentence_en : who believes in dreams in this modern age
# sentence : 1936
# sentence   : मैं भी दूर जाना भी चाहती हूं मैं देखती हूँ कि मेरे पति क्या कहते हैं
# translated : i dont know what about it was gonna take
# sentence_en : id like to go away too ill see what my husband says
# sentence : 1937
# sentence   : चलो फिर से कोशिश करते हैं
# translated : lets go go ahead away from the trident story
# sentence_en : lets try again
# sentence : 1938
# sentence   : वहअपनेहाथमें लेताहैऔर एक अंतिम कमरेमें आप सुराग
# translated : laughter he must be be a lot of course
# sentence_en : she takes your hand and leads you into a final room
# sentence : 1939
# sentence   : मेरे पास कई जवान फिल्म निर्माताओं है जो आ के कहते है यह करने के लिए मुझे कुछ सलाह दीजिये।
# translated : i just want to see you know what can
# sentence_en : i have young filmmakers come up to me and say give me some advice for doing this
# sentence : 1940
# sentence   : उन बैज़ो का क्या नाम रखा है या फ़िर कितने प्वाइंट उन्हें दिये गये और हम ये पूरे सिस्टम पर देखते हैं दसियों हज़ार पाँचवें या छठे के बच्चों को इधर से उधर भेज देता है कि आपने उन्हें कौन सा बैज दिया।
# translated : you get it down in the bunker
# sentence_en : just the wording of the badging or how many points you get for doing something we see on a systemwide basis like tens of thousands of fifthgraders or sixthgraders going one direction or another depending what badge you give them
# sentence : 1941
# sentence   : तुम्हारे पिता की मौत का बदला लेंगे
# translated : i think think he was just must have been
# sentence_en : we will avenge your fathers death
# sentence : 1942
# sentence   : ट्रेवर बस अब के लिए ieave ट्रेवर lνe लगभग मिल गया
# translated : ive got a lot of course course i was
# sentence_en : ill be right there
# sentence : 1943
# sentence   : मैं
# translated : laughter he cant just get rid of course course
# sentence_en : i
# sentence : 1944
# sentence   : रेगी के दर्द में
# translated : fortunately applause laughter he must be careful be careful
# sentence_en : in reggies pain
# sentence : 1945
# sentence   : और हम अफ्रीका में पहले से ही डूबे हुए हैं।
# translated : and thats how many many many idols were not
# sentence_en : and we in africa are already immersed
# sentence : 1946
# sentence   : चाचू ने कहा की अयूब को अब्बू की जगह काम करना होगा
# translated : but she must be be a lot bit little
# sentence_en : my uncle said that ayoub would take his place
# sentence : 1947
# sentence   : यहहास्यास्पदहै
# translated : laughter he cant just need to see you know
# sentence_en : thats ridiculous
# sentence : 1948
# sentence   : आप वह क्या चाहता है इस आदमी को नहीं दे सकता
# translated : what you can not even know the president
# sentence_en : you cannot give this guy what he wants
# sentence : 1949
# sentence   :  धत् तेरे की।  हैलो प्यारों।
# translated : laughter and then the hell is not gonna be
# sentence_en : blimey
# sentence : 1950
# sentence   : यह द लॉन्ग नाऊ फाउंडेशनthe long now foundation की परियोजना है जो tedsters के द्वारा स्थापित की गयी है जैसे कि केविन केली और स्टीवर्ट ब्रांड
# translated : i said see that was gonna be careful careful
# sentence_en : its a project by the long now foundation which was founded by tedsters including kevin kelly and stewart brand
# sentence : 1951
# sentence   : वस्तुतः बहुत से अमरीकी राज्यों में आपको कम सूचना चाहिए आपको कंपनी प्राप्त करने के लिए कम सूचना देनी होती है जबकि पुस्तकालय का कार्ड लेने के लिए ज्यादा।
# translated : i did you got a little bit bit bit
# sentence_en : in fact in a number of us states you need less information you need to provide less information to get a company than you do to get a library card
# sentence : 1952
# sentence   : और इसलिए हम किसी को चुनने का फैसला किया है
# translated : so we need to get your hand you need
# sentence_en : and so weve decided to select someone
# sentence : 1953
# sentence   : और तीसरी रात फ़िर वो उसे दो बार मोड देता था  और ये बहुत बहुत ही प्रसिद्ध टोपी बन जाती है
# translated : and thats why just had a lot of course
# sentence_en : and the third night he would give it two more folds  and this is a very very famous cap
# sentence : 1954
# sentence   : वो तो मैं
# translated : laughter he was just gonna get rid of course
# sentence_en : thats me
# sentence : 1955
# sentence   : दुनिया एक बुरी जगह है चार्ली है
# translated : hes just got a lot of course that was
# sentence_en : the world is an evil place charlie
# sentence : 1956
# sentence   : jorएल सही था यह अंत है
# translated : thats why is not gonna be careful get rid
# sentence_en : jorel was right this is the end
# sentence : 1957
# sentence   : रुको
# translated : hes not gonna get get rid in charge
# sentence_en : wait
# sentence : 1958
# sentence   : और मुझे यकीन है कि वे आश्चर्य करती होंगी जब यह जानेंगी कि वे सबसे पहली थीं कुछ ऐसा करने में जो अब दूसरे देशों में फैल रहा है जैसे मालावी ज़ेनज़ीबार द्वीप और घर के करीब यहाँ यूनाइटेड स्टेटस में न्यूयॉर्क शहर में।
# translated : i i was just want to be a lot
# sentence_en : and im sure shes in awe when she realizes that something that she helped to pioneer is now spreading to other countries like malawi the island of zanzibar and coming closer to home here in the unites states in the city of new york
# sentence : 1959
# sentence   : immunisation immunisation schedule for children in the uk
# translated : laughter i just want to be careful see your
# sentence_en : immunisation schedule for the uk
# sentence : 1960
# sentence   : हमने एगबोग्ब्लाेशी में ऐप का परीक्षण किया है आैर दूसरे स्थानों के लिए खाेल रहे हैं
# translated : i want the other
# sentence_en : weve tested the app in agbogbloshie and are getting ready to open it up to other maker ecosystems
# sentence : 1961
# sentence   : मैं डेकिन्स हूँ
# translated : im sorry sorry
# sentence_en : im dekins
# sentence : 1962
# sentence   : वे बचपन शादी का सामना और जानलेवा जल्दी गर्भावस्था का सामना।
# translated : lets take care of course course i was a
# sentence_en : they face early childhood marriage and they face lifethreatening early pregnancy
# sentence : 1963
# sentence   : और धन्यवाद
# translated : ca laughter applause thank you need to be your
# sentence_en : and thanks
# sentence : 1964
# sentence   :  उस द्वीप से बच कभी नहीं होगा
# translated : never never get rid of course i was gonna
# sentence_en :  he can never escape the island
# sentence : 1965
# sentence   : यहाँ के माध्यम से देखो
# translated : heres the hell is the hell is not gonna
# sentence_en : look through here
# sentence : 1966
# sentence   : यह शहद सब ठीक है
# translated : thats all right now its velvet 700 him native
# sentence_en : its all right honey
# sentence : 1967
# sentence   : इसलिए मैंने विरोध के लिए विशिष्ट चीजों का निर्माण किया चीजें जो इस आध्यात्मिक युद्ध मे हथियार का काम करेंगी चीजें जो लोगों को एक आवाज़ देंगी और जो उन्हें आगे बढ़ने मे मदद करेंगी
# translated : they can take care of course the hell are
# sentence_en : so i started making things specific to the protest things that would be weapons in a spiritual war things that would give people voice and things that would fortify them for the road ahead
# sentence : 1968
# sentence   : फ़ोटो खिंचवाने के लिए मुस्कुराओ।
# translated : hes so heres the hell is the hell is
# sentence_en : smile for the camera
# sentence : 1969
# sentence   : और हमे लगे कि हम वाकई सुर मे सुर मिला रहे हैं
# translated : and were were gonna be in the most russians
# sentence_en : and wed know that we had a real rhythm going
# sentence : 1970
# sentence   :  शर्म आनी चाहिए
# translated : laughter and hes not gonna get rid of course
# sentence_en :  shame
# sentence : 1971
# sentence   : मुझे एक दो दिन में मिल सकती है
# translated : i got a lot of course the hell is
# sentence_en : i can get it in a couple of days
# sentence : 1972
# sentence   : वांडा
# translated : laughter applause he must be careful easy so heres
# sentence_en : wanda
# sentence : 1973
# sentence   : हमारा प्रयास था ऐसे जीनोम की सोच जो सेल के आपरेटिंग सिस्टम की तरह कार्य करे  कोशिका में आवश्यक पूर्ण हार्डवेयर हो जो जीनोम को क्रियाशील कर सके
# translated : i cant do not just get rid he was
# sentence_en : our approach was to think of the genome as the operating system of the cell with the cell containing the hardware necessary to boot up the genome
# sentence : 1974
# sentence   : डेव।
# translated : greg how many medals no rank got a lot
# sentence_en : dave
# sentence : 1975
# sentence   : चतुरता से काम करिये फिर कड़ी मेहनत करिये  यह पीछे का चित्र सुबह के 3 बजे का हैं
# translated : lets take care of course i cant want to
# sentence_en : so i always tell my students work smart then work hard
# sentence : 1976
# sentence   : मुझे मत छुओ
# translated : dont let me that was a lot lot of
# sentence_en : dont touch me
# sentence : 1977
# sentence   : लेकिन ये देखने का मौका है उनकी अपनी आजीविका है ।
# translated : hes just have a lot of course course he
# sentence_en : but these are a chance to see their own livelihoods
# sentence : 1978
# sentence   : पर उसके लिए हमें प्रयोगशाला के अंदर का वीडियो चाहिए इन जानवरों के साथ हो रही क्रूरता का वीडियो चाहिए।
# translated : they were just want want to be ashamed my
# sentence_en : but to do so we need video from inside the lab footage of the horrible atrocities being committed against the animals
# sentence : 1979
# sentence   : तो इसके बारे में क्या किया जाए
# translated : what did did you should not gonna be a
# sentence_en : so what can you do about that
# sentence : 1980
# sentence   : उन्हें अपने काम से लगाव है
# translated : hes just got a lot of course course he
# sentence_en : you know that passion for what theyre doing
# sentence : 1981
# sentence   : हम में से बाकी लिए हम बाहर जाना है आप ही भाषण देने के लिए जा रहे हैं
# translated : we are we have to go to be be
# sentence_en : are you going to give the same speech for the rest of us when we go out
# sentence : 1982
# sentence   : और कभीकभी हम पटरी से उतर सकते हैं।
# translated : we can have see your hips course he must
# sentence_en : and sometimes we can get off track
# sentence : 1983
# sentence   : तुम आ गए
# translated : hey youre gonna get rid of course he didnt
# sentence_en : have you come
# sentence : 1984
# sentence   : तुम जाकर उसे ला सकते हो
# translated : can you can be the car get rid of
# sentence_en : cant you go get him
# sentence : 1985
# sentence   : मैं metzger विदेशी भेजने के लिए किया था श्री hatto और उनकी पत्नी का दौरा करने के लिए।
# translated : he was just wanted to kill him down to
# sentence_en : i had to send metzger overseas to pay mr hatto and his wife a visit
# sentence : 1986
# sentence   :  मैं यह करूँगा
# translated : laughter i will be really good morning morning long
# sentence_en :  i will do it
# sentence : 1987
# sentence   : आप कैसे जुगनू इस से बेखबर तो स्पष्ट हो सकता है
# translated : how can do you get rid you got a
# sentence_en : how could you be oblivious to this firefly so obvious
# sentence : 1988
# sentence   : हमारी अर्ज़ी नामंजूर कर दी गई हँसी इस आधार पर रिज़र्व बैंक ने कहा कि वह ऐसे बैंक को लाइंसेंस नहीं दे सकता जिसे प्रोत्ससाहन करने वाले सदस्य अनपढ़ हैं।
# translated : i cant just want to be the way
# sentence_en : our license was rejected  laughter on the grounds  reserve bank said that we cannot issue a license to the bank whose promoting members who are nonliterate
# sentence : 1989
# sentence   : यह एक व्यापारी जो सीढ़ी चढ़ रहा है फिर सीढी शेयर मार्केट ग्राफ बन जाती है या डॉलर के निशान वाली कोई चीज जो ठीक लगे
# translated : i still really right now
# sentence_en : you know its the businessman climbing up a ladder and then the ladder moves morphs into a stock market graph and anything with dollar signs thats always good
# sentence : 1990
# sentence   : फ़ॉन्ट रंग   d900d9 व्यक्ति उर्दू में चिल्ला
# ...
# translated : nothing try in your hips pummel course not gonna
# sentence_en : this hellfire club its got to be something else
# sentence : 2924
# sentence   : तुम्हें मैं सिरफिरा लगता हूँ।
# translated : im not gonna get in the the other
# sentence_en : you think im crazy
# sentence : 2925
# sentence   : आप सभी का जीवन मगलमय हो
# translated : you go home of course course i think love
# sentence_en : laughter live long and prosper
# sentence : 2926
# sentence   : और अगर आप एक रडार हैं यह एक बुरा काम है
# translated : and you have a good morning fucking mystery percentage
# sentence_en : and if youre a radar thats a really bad job
# sentence : 2927
# sentence   : मैंबंधे
# translated : theoretically hes sounding not gonna be careful be careful
# sentence_en : i tied
# sentence : 2928
# sentence   : हंसी किन्तु कभी नहीं हा हा हा हा हा।
# translated : oh no they must have a lot of course
# sentence_en : laughter but never like ha ha ha ha la
# sentence : 2929
# sentence   : ये मेरे मित्र क्रिस के साथ मेरी फोटो है प्रशांत महासागर के तट पर
# translated : i was just like a few little bit considerable
# sentence_en : heres a picture of me and my friend chris on the coast of the pacific ocean
# sentence : 2930
# sentence   : और में आप से एक और गुज़ारिश करूँगी
# translated : and i have a good morning photo
# sentence_en : and id also like to ask you a favor
# sentence : 2931
# sentence   : और फिर हम मुलाक़ात के बारे में बात करेंगे मैं वादा करता हूँ।
# translated : and i i think we need to be a
# sentence_en : and then we will talk about visitation i promise
# sentence : 2932
# sentence   : औरफिरभी हम इस तरह हैं हम नहीं कर रहे हैं
# translated : we dont even know the world
# sentence_en : and yet we are like that arent we
# sentence : 2933
# sentence   : चारों ओर यही है
# translated : hes hes just not gonna even gonna be careful
# sentence_en : it floats around
# sentence : 2934
# sentence   :  लेकिन अंत में मैं बाबुल   मैं में प्रवेश के लिए एक काफी आसान मालकिन थी मानना  सिकंदर  मैं सभी से प्यार करता था  वह छोड़ गया था की तुलना में
# translated : i thought i was just need to be the
# sentence_en : but in the end i believe babylon was a far easier mistress to enter than she was to leave
# sentence : 2935
# sentence   : एक तो ये कि आप मर्दाना की स्पेलिंग ठीक लिखें।
# translated : you know what about the beginning just have a
# sentence_en : one i care that you spell it right
# sentence : 2936
# sentence   : यह स्थिति 2050 में होने की भविष्यवाणी की है
# translated : its just like a lot of course course why
# sentence_en : this is the situation thats predicted to happen in 2050
# sentence : 2937
# sentence   : 2005 के बाद से कंबोडिया में अनाथालयों की संख्या में 75 प्रतिशत की वृद्धि हुई है और कंबोडिया के अनाथालयों में रह रहे बच्चों की संख्या लगभग दोगुनी हो गई है इस तथ्य के बावजूद कि इन अनाथालयों में रह रहे बहुधा बच्चे पारंपारिक दृष्टि से अनाथ नहीं हैं।
# translated : i dont not even gonna get rid you know
# sentence_en : since 2005 the number of orphanages in cambodia has risen by 75 percent and the number of children living in cambodian orphanages has nearly doubled despite the fact that the vast majority of children living in these orphanages are not orphans in the traditional sense
# sentence : 2938
# sentence   : टहलने के लिए इस जोकर लो
# translated : so how many many long people are you know
# sentence_en : take this clown for a walk
# sentence : 2939
# sentence   : उसे पागल कहा और नौकरी से निकाल दिया।
# translated : and he said just wanted to leave him down
# sentence_en : she was called crazy and fired
# sentence : 2940
# sentence   : मैं पैरिस की सुरंगों में जा रहा था उसकी छतों पर भी अपने दोस्तों के साथ
# translated : im not gonna be careful a little bit bit
# sentence_en : i was going in the tunnels of paris on the rooftops with my friends
# sentence : 2941
# sentence   : सबि  लेकिन केवल स्टेनटर एक कोशकीय है।
# translated : hes just a lot of course course he was
# sentence_en : sb but a stentor is only a single cell
# sentence : 2942
# sentence   : और उन्होंने सीख की वे सब अकेले भी बदलाव ला सकते है और उन्होंने सीख की वे सब अकेले भी बदलाव ला सकते है
# translated : they can all right right
# sentence_en : and they learned that individually they could each make a difference but together they created an impact
# sentence : 2943
# sentence   : लेकिन यहाँ नमी नहीं है
# translated : but heres hes just got a lot of course
# sentence_en : but it isnt damp here
# sentence : 2944
# sentence   : उन्हें ये बताने मे कोइ परेशानी नही है कि कला किस बारे मे है
# translated : hes not just trying gonna get rid you know
# sentence_en : they have no trouble telling us what art is about
# sentence : 2945
# sentence   : ट्रक पर जाओ
# translated : lets go on the phone phone ringing phone ringing
# sentence_en : go to the truck
# sentence : 2946
# sentence   : और कबीले
# translated : laughter applause hes sounding i just need need to
# sentence_en : and clan
# sentence : 2947
# sentence   : ऐसा नहीं है की एक लानत थोड़ा कुछ नहीं के लिए मायने रखती है
# translated : nothing nothing have to be a lot of course
# sentence_en : not a damn bit of it matters for nothin
# sentence : 2948
# sentence   : तालियाँ इससे पहले की में यह विडियो आपको दिखाऊ में आपको बताना चाहता हूँ की यह उन्होंने पिछले ३ दिनों में बनाया है क्रिस का फ़ोन आने के बाद
# translated : i want you want to go to kill him
# sentence_en : applause so before i play this video i want to tell you that they created it in the last three days after getting a call from chris
# sentence : 2949
# sentence   : हम उसे नहीं खोज रहे हैं
# translated : why dont want want to be a lot of
# sentence_en : were not looking for that
# sentence : 2950
# sentence   : यह कलम जैसी चीज़ एक फूट लम्बी है
# translated : its a lot of course course i was just
# sentence_en : that sort of phallic bit there is about a foot long
# sentence : 2951
# sentence   : क्योंकि मैं एक प्रतिभाशाली चालक हूँ।
# translated : im not a gonna gonna be a little bit
# sentence_en : because im a brilliant driver
# sentence : 2952
# sentence   : और मेरे लिए मुश्किल हिस्सा उस एक चीज़ का जो हमें संपर्क से बाहर रखती है है हमारा ये डर कि हम संपर्क के काबिल नहीं हैं ये एक ऐसी चीज़ थी जिससे व्यक्तिगत रूप से और व्यावसायिक रूप से मुझे महसूस हुआ कि मुझे ज़्यादा बेहतर तरीके से इसे समझने कि ज़रूरत है
# translated : i have only one thing
# sentence_en : and to me the hard part of the one thing that keeps us out of connection is our fear that were not worthy of connection was something that personally and professionally i felt like i needed to understand better
# sentence : 2953
# sentence   : वालर कठपुतली मास्टर है।
# translated : hes so heres the fhrer is your cousin laughter
# sentence_en : waller is the puppet master
# sentence : 2954
# sentence   : यहाँ तक कि आधी रात को भी।
# translated : why should not gonna be a lot of course
# sentence_en : even in the middle of the night
# sentence : 2955
# sentence   : अब एक ठीकठाक व्ययस्क को किशोरों के बचाव के लिए यह us में रखना एक समाधान नही होगा पुलिस के युवाओं से सवाल पूछने की तरीकों से
# translated : i could be a lot of course me
# sentence_en : now having an appropriate adult safeguard for juveniles here in the us would not be a cureall for improving police questioning of youth
# sentence : 2956
# sentence   : ईबेय ने कैदियों के कश्मकश में पहला कदम उठा कर एक पूर नया बाज़ार खडा कर दिया पुराने ग्राहकों के अनुभव को साझा करने का तरीका निकाल कर  कमेंट जिसने कैदियों को कश्मकश को आश्वासन के खेल में तब्दील कर दिया।
# translated : what do you mean the car
# sentence_en : ebay solved the prisoners dilemma and created a market where none would have existed by creating a feedback mechanism that turns a prisoners dilemma game into an assurance game
# sentence : 2957
# sentence   : आप में से कुछ इसे जानते होंगे
# translated : you can get out of course the hell is
# sentence_en : some of you will know it
# sentence : 2958
# sentence   : मैं इस के बारे में हम बात कर रहे थे एक जासूस था
# translated : i were just think about it was gonna get
# sentence_en : i thought this was a spy we were talking about
# sentence : 2959
# sentence   : हम एक समस्या हो सकता है।
# translated : can we can have a good morning day take
# sentence_en : we might have a problem
# sentence : 2960
# sentence   : हमने सीखा है कि सबसे प्रभावशाली आपातकालीन प्रणाली वास्तव में रोज़मर्रा की प्रणाली है और उस प्रणाली को हर समुदाय तक पहुँचना है एमील के ग्रामीण समुदायों समेत।
# translated : i i was just like a lot of course
# sentence_en : weve learned that the most efficient emergency system is actually an everyday system and that system has to reach all communities including rural communities like emiles
# sentence : 2961
# sentence   : थोड़ा सा
# translated : greg laughter but heres the car yo car 45000
# sentence_en : little bit
# sentence : 2962
# sentence   : जिम मैं चालान और हार्मोन उपचार पढ़ा वे 300 डॉलर एक शॉट की लागत
# translated : i i said have a lot of course the
# sentence_en : jim i read the invoice and hormone treatments they cost 300 a shot
# sentence : 2963
# sentence   : जैसे केवल अस्पताल होना पर्याप्त नहीं है।
# translated : theres no hes just one name name of course
# sentence_en : like its not enough to have a hospital
# sentence : 2964
# sentence   : इस थिएटर नहीं है
# translated : aint so heres the hell was gonna be careful
# sentence_en : this aint the theatre
# sentence : 2965
# sentence   : धन्यवाद धन्यवाद
# translated : thank you you have been very much else him
# sentence_en : thank you thank you
# sentence : 2966
# sentence   : मैं इस बारे में ज्यादा परवाह नहीं करता की जहाँ से हमने शुरुआत की थी हम वावस वही पहुच गए है
# translated : i havent been been in the worst
# sentence_en : i dont care much for this pretending were back where we started
# sentence : 2967
# sentence   : हाँ ईस्पोर्ट्स है पुरस्कार हैं पैसा बनाने का अवसर है प्रतिस्पर्धात्मक तरीके से। 2 4856
# translated : they always have been a lot of course i
# sentence_en : yes theres esports theres prizes theres the opportunity to make money in a competitive way
# sentence : 2968
# sentence   : मै कभी आपको नही कहूँंगी तनाव मुक्त हो जाये
# translated : i want you want to go ahead to get
# sentence_en : i no longer want to get rid of your stress
# sentence : 2969
# sentence   : तो कोई भी नहीं मिल सकता एक्स आप से ज्यादा सही नं  और गधे
# translated : and you got some lots of course he was
# sentence_en : so no one can find the x but you right
# sentence : 2970
# sentence   : विक
# translated : laughter applause then he was just got a lot
# sentence_en : vic
# sentence : 2971
# sentence   : जानती हूँ कि वे एएलएफ़ के कमीने मुझे क्या बुलाते हैं।
# translated : what they can do not a lot of course
# sentence_en : i know what theyre calling me those alf fuckers
# sentence : 2972
# sentence   : इसकी विरासत दीर्घ काल तक रहेगी पर पूर्णतः बुरी नहीं होगी जिन नए तरीकों सामाजिक सेवाओं और प्रणालियों को हम विकसित करेंगे वह सबके भले के लिए प्रयोग की जा सकेंगी।
# translated : we need to the the
# sentence_en : its legacy will be longlasting but not all bad the breakthroughs social services and systems we develop can be used to the betterment of everyone
# sentence : 2973
# sentence   : चलो कहते हैं  बूढ़े आदमी एक नाजायज बच्चे मान लीजिए उनके धन में से कुछ पाने के लिए कोशिश कर रहा था
# translated : some some good to see you know what happened
# sentence_en : lets say suppose the old man has an illegitimate child who was trying to get some of his money
# sentence : 2974
# sentence   : आखिर में मैं यह ही कहना चाहूँगी कि हमारे पास गज़ब का मौका है गरीबी को जडमूल सहित नष्ट कर डालने का।
# translated : i can only only one the only one car
# sentence_en : i want to end just by saying that theres enormous opportunity to make poverty history
# sentence : 2975
# sentence   : यह वही भावात्मा है जो हमें बीमारी मृत्यु और तबाही से दूर रखता है।
# translated : and thats why dont know what the other way
# sentence_en : it is the spirit that binds us from sickness death and destruction
# sentence : 2976
# sentence   : उसे मत छोड़ो।
# translated : they dont want want to go to take care
# sentence_en : dont leave him
# sentence : 2977
# sentence   : बस एक पनीर सैंडविच आपको मजबूत निर्णय लेने के लिए जरूरी है चीज हमारा एक दोस्त कैसे है पनीर और मांस खाने से स्व नियंत्रण को बढ़ावा दिया सकता है इस बिंदु पर आप सोच रहे हो सकते है क्या मुझसे कुछ छुट गया है
# translated : you believe you got in my shoe mother fault
# sentence_en : a cheese sandwich is all you need for strong decisionmaking what a friend we have in cheeses eating cheese and meat may boost selfcontrol at this point you might be wondering did i miss something
# sentence : 2978
# sentence   : बोलो
# translated : laughter he must be punished have a lot of
# sentence_en : say it
# sentence : 2979
# sentence   : 1964 अमेरिका के परिवार छोटे और लोगों की आयु लम्बी होती थी वियतनाम के परिवार बड़े और लोगों की जीवन आयु छोटी होती थी और जो होता है वह यह है
# translated : laughter and i dont know what if they dont
# sentence_en : 1964 america had small families and long life vietnam had large families and short lives
# sentence : 2980
# sentence   : अगर तुम सीधे चलोगे और बांये मुड जाओगे तो दायी तरफ़ का चौथा मकान
# translated : you can keep you put it was gonna find
# sentence_en : if you go straight and turn left fourth house on the right side
# sentence : 2981
# sentence   : लेकिन अंत में मुझे पता था कि या तो मैं या वे और मैंने खुद को चुना।
# translated : i i said will take care of course it
# sentence_en : but in the end i knew its either me or them and i chose myself
# sentence : 2982
# sentence   : got it
# translated : laughter he was just never saw gonna be careful
# sentence_en : got it
# sentence : 2983
# sentence   : अब तुम्हारा मौक़ा है।
# translated : hes just got a lot of course my wife
# sentence_en : heres your chance
# sentence : 2984
# sentence   :  कितनी हैं
# translated : laughter and he must be careful be careful back
# sentence_en :  how many pieces
# sentence : 2985
# sentence   : अगर वो भेज सकते हैं
# translated : they can take care of course course i will
# sentence_en : if they can
# sentence : 2986
# sentence   : क्योंकि तुम्हारे साथ खेलने में मजा आता हैं
# translated : so lets go get rid out of course course
# sentence_en : because youre so fun to play with
# sentence : 2987
# sentence   : दुर्भाग्य से ये आधी जरमन हैं वो इतनी सूक्ष्मता से नापझोक करती हैं।
# translated : they want to see you know him
# sentence_en : unfortunately theyre almost half german theyre so precise
# sentence : 2988
# sentence   : आज यह उसके लिए कठिन है
# translated : hes so heres the hell is she has been
# sentence_en : its her last of the day
# sentence : 2989
# sentence   : एयरहड़ताल
# translated : laughter applause laughter applause thank you mean you mean
# sentence_en : air strike
# sentence : 2990
# sentence   : प्रेज़ीडेंट होना कैसा लगता है
# translated : how does he could never get rid in charge
# sentence_en : so whats it like being president
# sentence : 2991
# sentence   : बस बस।
# translated : laughter applause hes just trying so sorry much they
# sentence_en : there there
# sentence : 2992
# sentence   : हम कर रहे हैं पर वे अभी भी मौजूद हैं
# translated : they still just got a lot of course course
# sentence_en : we have and theyre still here
# sentence : 2993
# sentence   :  आप क्या कह रहे हैं
# translated : what youre gonna see you know what are you
# sentence_en :  yes i saw a ghost
# sentence : 2994
# sentence   : वे सरलता से बाहर निकलते और सील मछली की खाल से बनी अपनी पतलून उतारकर अपने हाथ में विष्‍ठा कर लेते। जैसे ही विष्‍ठा ठंड के कारण जमने लगती वे उसे एक ब्‍लेड का आकार दे देते हैं।
# translated : i i was just saw think it was gonna
# sentence_en : he simply slipped outside pulled down his sealskin trousers and defecated into his hand and as the feces began to freeze he shaped it into the form of a blade
# sentence : 2995
# sentence   : हम यहाँ ऊपर की ओर से लड़ रहे हैं
# translated : theyre are not a lot of course course i
# sentence_en : were fighting uphill here
# sentence : 2996
# sentence   : अकेले एक साल चलो
# translated : lets take her us
# sentence_en : a year alone come on
# sentence : 2997
# sentence   : और जानती हैं मेरी माँ ने हमें सिखाया
# translated : and then he was just gonna be reinstalled disrespectful
# sentence_en : and you know my mother taught us
# sentence : 2998
# sentence   : तुमनेमेरी पूरी ज़िंदगी गया
# translated : greg laughter applause he must never have been a
# sentence_en : since i was a boy
# sentence : 2999
# sentence   : आपको लगता है कि कुछ बड़ा पाने के लिए होगा
# translated : you should have to be a lot of course
# sentence_en : whered you get something that big
# sentence : 3000

# %%
import pandas as pd
df1=pd.Series(sentence_en_list).to_frame()
df2=pd.Series(translated_list).to_frame()
df1.shape,df2.shape
# Out:
# ((3000, 1), (3000, 1))

# %%
#sentence_en_list=[]
#translated_list=[]

# %%
def Splitfunction(strval):
  return strval.split()

# %%
df1["sentence"]=df1[0].apply(Splitfunction)
df2["translated"]=df2[0].apply(Splitfunction)

# %%
df1["sentence"]
# Out:
# 0                        [almost, calls, for, a, snuggie]
# 1       [were, here, for, security, and, drone, mainte...
# 2       [this, is, not, because, i, am, a, better, per...
# 3       [so, theres, an, interesting, pattern, but, we...
# 4       [and, certainly, lots, of, people, have, taken...
#                               ...
# 2995                       [were, fighting, uphill, here]
# 2996                           [a, year, alone, come, on]
# 2997             [and, you, know, my, mother, taught, us]
# 2998                              [since, i, was, a, boy]
# 2999             [whered, you, get, something, that, big]
# Name: sentence, Length: 3000, dtype: object

# %%
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu
# Prepare the reference sentences and candidate sentences for multiple translations
#references = [['I', 'love', 'eating', 'ice', 'cream'], ['He', 'enjoys', 'eating', 'cake']]
#translations = [['I', 'love', 'eating', 'ice', 'cream'], ['He', 'likes', 'to', 'eat', 'cake']]

# Create a list of reference lists
#references_list = [[ref] for ref in references]

# Calculate BLEU score for the entire corpus
bleu_score_corpus = corpus_bleu(list(df1["sentence"]), list(df2["translated"]),weights=(0, 0, 0, 1))
print("Corpus BLEU Score: ", bleu_score_corpus)

bleu1 = corpus_bleu(list(df1["sentence"]), list(df2["translated"]), weights=(1.0, 0, 0, 0))
bleu2 = corpus_bleu(list(df1["sentence"]), list(df2["translated"]), weights=(0.5, 0.5, 0, 0))
bleu3 = corpus_bleu(list(df1["sentence"]), list(df2["translated"]), weights=(0.3, 0.3, 0.3, 0))
bleu4 = corpus_bleu(list(df1["sentence"]), list(df2["translated"]), weights=(0.25, 0.25, 0.25, 0.25))
print('BLEU-1: {:.4f}'.format(bleu1))
print('BLEU-2: {:.4f}'.format(bleu2))
print('BLEU-3: {:.4f}'.format(bleu3))
print('BLEU-4: {:.4f}'.format(bleu4))
# Out:
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Corpus BLEU Score:  2.2250738585072626e-308
# BLEU-1: 0.0602
# BLEU-2: 0.0016
# BLEU-3: 0.0000
# BLEU-4: 0.0000

# %%
# !pip install jiwer
# !pip install nltk
# !pip install sacrebleu
# !pip install sacremoses

# %%
# !pip install evaluate

# %%
list(df1[0])

# %%
import evaluate
bleu = evaluate.load('bleu')

references=[ [li] for li in list(df1[0])]
predictions=list(df2[0])

results = bleu.compute(predictions=predictions, references=references)
print(results)
# Out:
# {'bleu': 0.00788679600497459, 'precisions': [0.122828978250665, 0.02003190923595107, 0.00424248619914128, 0.000603536725209729], 'brevity_penalty': 0.8852456002789404, 'length_ratio': 0.891352859135286, 'translation_length': 25564, 'reference_length': 28680}
