# %% [markdown]
# # **Load Modules**

# %%
# !pip install Pillow
# !pip install Keras-Preprocessing
# !pip install ktrain

# %%
import numpy as np
import pandas as pd
import nltk
import tensorflow as tf
from nltk.corpus import stopwords
from nltk.corpus import reuters
from nltk.corpus import brown
from nltk.corpus import gutenberg
from nltk.tokenize import RegexpTokenizer
from nltk.stem import SnowballStemmer

import seaborn as sns
import plotly.express as px
import pickle
import joblib
from collections import Counter
from textblob import Word
from wordcloud import WordCloud
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC, SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, AdaBoostClassifier, VotingClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, f1_score, recall_score
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential, load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.utils.np_utils import to_categorical
from keras.layers import Activation, Dense, Embedding, LSTM, SpatialDropout1D, Dropout, Flatten, GRU, Conv1D, MaxPooling1D, Bidirectional
from wordcloud import WordCloud,ImageColorGenerator
from PIL import Image
import urllib
import requests
import re
import ktrain
from ktrain import text
import matplotlib.pyplot as plt
from keras_preprocessing.sequence import pad_sequences

sns.set()
# %matplotlib inline

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('gutenberg')
nltk.download('brown')
nltk.download("reuters")
nltk.download('words')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package reuters to /root/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
datafolder='/content/drive/MyDrive/Community Help /category classification/Data/'
modelfolder='/content/drive/MyDrive/Community Help /category classification/Model/'
arrayfolder='/content/drive/MyDrive/Community Help /category classification/NumPyArrays/'

# %% [markdown]
# # **Data Preparation for Machine Learning**

# %% [markdown]
# ### **Help Methods**

# %% [markdown]
# ###### DataLoad and process ( Methods )

# %%
def DataPreparationforML(filename):
  df_category_model = pd.read_csv(datafolder+filename)
  df_category_model.drop(columns=['Unnamed: 0'],inplace=True)
  #print(filename +' Shape : '+df_category_model.shape)
  df_category_model['TITLE']=df_category_model['TITLE'].fillna("")
  df_category_model.isna().sum()
  df_category_model['lower_case'] = df_category_model['TITLE'].apply(lambda x: x.lower().strip().replace('\n', ' ').replace('\r', ' '))
  df_category_model['alphabatic'] = df_category_model['lower_case'].apply(lambda x: re.sub(r'[^a-zA-Z\']', ' ', x)).apply(lambda x: re.sub(r'[^\x00-\x7F]+', '', x))
  df_category_model['without-link'] = df_category_model['alphabatic'].apply(lambda x: re.sub(r'http\S+', '', x))
  tokenizer = RegexpTokenizer(r'\w+')
  df_category_model['Special_word'] = df_category_model.apply(lambda row: tokenizer.tokenize(row['lower_case']), axis=1)
  stop = [word for word in stopwords.words('english') if word not in ["my","haven't","aren't","can","no", "why", "through", "herself", "she", "he", "himself", "you", "you're", "myself", "not", "here", "some", "do", "does", "did", "will", "don't", "doesn't", "didn't", "won't", "should", "should've", "couldn't", "mightn't", "mustn't", "shouldn't", "hadn't", "wasn't", "wouldn't"]]
  df_category_model['stop_words'] = df_category_model['Special_word'].apply(lambda x: [item for item in x if item not in stop])
  df_category_model['stop_words'] = df_category_model['stop_words'].astype('str')
  df_category_model['short_word'] = df_category_model['stop_words'].str.findall('\w{2,}')
  df_category_model['string']=df_category_model['short_word'].str.join(' ')
  df_category_model['TITLE2'] = df_category_model['string'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
  return df_category_model

# %% [markdown]
# ###### ApplyNgram ( Methods )

# %%
def ApplyNgramAndSave(df_category_model,model):
  x_train, x_test, y_train, y_test = train_test_split(df_category_model["TITLE2"],df_category_model["CATEGORY_CLASS_NEW"], test_size = 0.25, random_state = 42)
  count_vect = CountVectorizer(ngram_range=(1, 2), max_features = 2000)
  transformer = TfidfTransformer(norm='l2',sublinear_tf=True)
  x_train_counts = count_vect.fit_transform(x_train)
  x_train_tfidf = transformer.fit_transform(x_train_counts)
  x_test_counts = count_vect.transform(x_test)
  x_test_tfidf = transformer.transform(x_test_counts)
  print (x_train_tfidf.shape,x_test_tfidf.shape, y_train.shape, y_test.shape)
  joblib.dump(x_train_counts, arrayfolder+'x_train_counts_'+model+'.pkl')
  joblib.dump(x_train_tfidf, arrayfolder+'x_train_tfidf_'+model+'.pkl')
  joblib.dump(x_test_counts, arrayfolder+'x_test_counts_'+model+'.pkl')
  joblib.dump(x_test_tfidf, arrayfolder+'x_test_tfidf_'+model+'.pkl')
  joblib.dump(x_train, arrayfolder+'x_train_'+model+'.pkl')
  joblib.dump(x_test, arrayfolder+'x_test_'+model+'.pkl')
  joblib.dump(y_train, arrayfolder+'y_train_'+model+'.pkl')
  joblib.dump(y_test, arrayfolder+'y_test_'+model+'.pkl')
  joblib.dump(count_vect, arrayfolder+'count_vect_'+model+'.pkl')

# %% [markdown]
# ###### Visualization ( Methods )

# %%
def Visualization(df_category_model):
  fig = plt.figure(figsize=(14,7))
  df_category_model['length'] = df_category_model.TITLE2.str.split().apply(len)
  ax1 = fig.add_subplot(122)
  sns.histplot(df_category_model['length'], ax=ax1,color='green')
  describe = df_category_model.length.describe().to_frame().round(2)
  ax2 = fig.add_subplot(121)
  ax2.axis('off')
  font_size = 14
  bbox = [0, 0, 1, 1]
  table = ax2.table(cellText = describe.values, rowLabels = describe.index, bbox=bbox, colLabels=describe.columns)
  table.set_fontsize(font_size)
  fig.suptitle('Distribution of text length for text.', fontweight='bold',fontsize = 25)
  plt.show()

  sns.set_theme(style="whitegrid")
  plt.tick_params(axis = 'y', left = False, right = True, labelleft = False, labelright = True)
  plt.xticks(rotation = 90)
  sns.countplot(x=df_category_model["CATEGORY_CLASS_NEW"],facecolor=(0, 0, 0, 0),linewidth=5,edgecolor=sns.color_palette("BrBG", 2),orient='h')
  plt.title('Count by Class ', fontweight='bold',fontsize = 25)
  plt.show()

# %%
def Visualization2(df_category_model,category_clss):
  text=df_category_model[df_category_model['CATEGORY_CLASS_NEW']==category_clss]
  top = Counter([item for sublist in text['short_word'] for item in sublist])
  temp_positive = pd.DataFrame(top.most_common(20))
  temp_positive.columns = ['Common_words','count']
  fig = px.bar(temp_positive, x="count", y="Common_words", title='<b>Most Commmon Words in ( '+category_clss+" ) <b>", orientation='h',
             width=700, height=700,color='Common_words')
  fig.update_layout(
    font=dict(

        size=12,  # Set the font size here
    )
   )
  fig.show()

# %%
def Visualization3(df_category_model,category_clss):
  normal_words =' '.join([text for text in df_category_model['TITLE2'][df_category_model['CATEGORY_CLASS_NEW'] == category_clss]])
  wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
  plt.figure(figsize=(10, 7))
  plt.imshow(wordcloud, interpolation="bilinear")
  plt.axis('off')
  plt.title("WordCloud ( " + category_clss +" )",fontweight='bold',fontsize = 25)
  plt.show()

# %% [markdown]
# ---
#
# ### **MODEL #1**
#
# ---

# %%
df_category_model1=DataPreparationforML('df_category_model1.csv')

# %% [markdown]
# ###### **Visualization Model #1**

# %%
Visualization(df_category_model1)

# %%
list(set(df_category_model1["CATEGORY_CLASS_NEW"]))
# Out:
# ['GENERAL-1', 'SCIENCE & TECHNOLOGY', 'BUSINESS', 'ENTERTAINMENT', 'POLITICS']

# %%
Category_class1=list(set(df_category_model1["CATEGORY_CLASS_NEW"]))

# %%
for catcls in Category_class1:
  Visualization2(df_category_model1,catcls)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9399c288-68a5-4ead-89f4-44bdf6e3133b" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9399c288-68a5-4ead-89f4-44bdf6e3133b")) {                    Plotly.newPlot(                        "9399c288-68a5-4ead-89f4-44bdf6e3133b",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"39","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"39","offsetgroup":"39","orientation":"h","showlegend":true,"textposition":"auto","x":[24685],"xaxis":"x","y":["39"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"ap","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"ap","offsetgroup":"ap","orientation":"h","showlegend":true,"textposition":"auto","x":[12663],"xaxis":"x","y":["ap"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"new","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"new","offsetgroup":"new","orientation":"h","showlegend":true,"textposition":"auto","x":[12283],"xaxis":"x","y":["new"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"said","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"said","offsetgroup":"said","orientation":"h","showlegend":true,"textposition":"auto","x":[11314],"xaxis":"x","y":["said"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"he","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"he","offsetgroup":"he","orientation":"h","showlegend":true,"textposition":"auto","x":[10571],"xaxis":"x","y":["he"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"will","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"will","offsetgroup":"will","orientation":"h","showlegend":true,"textposition":"auto","x":[9255],"xaxis":"x","y":["will"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"first","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"first","offsetgroup":"first","orientation":"h","showlegend":true,"textposition":"auto","x":[8775],"xaxis":"x","y":["first"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"two","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"two","offsetgroup":"two","orientation":"h","showlegend":true,"textposition":"auto","x":[8672],"xaxis":"x","y":["two"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"us","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"us","offsetgroup":"us","orientation":"h","showlegend":true,"textposition":"auto","x":[8307],"xaxis":"x","y":["us"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"not","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"not","offsetgroup":"not","orientation":"h","showlegend":true,"textposition":"auto","x":[8146],"xaxis":"x","y":["not"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"one","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"one","offsetgroup":"one","orientation":"h","showlegend":true,"textposition":"auto","x":[7528],"xaxis":"x","y":["one"],"yaxis":"y","type" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d65264ff-abb2-4d4c-9348-eb102dc46ccd" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d65264ff-abb2-4d4c-9348-eb102dc46ccd")) {                    Plotly.newPlot(                        "d65264ff-abb2-4d4c-9348-eb102dc46ccd",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"new","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"new","offsetgroup":"new","orientation":"h","showlegend":true,"textposition":"auto","x":[16308],"xaxis":"x","y":["new"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"google","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"google","offsetgroup":"google","orientation":"h","showlegend":true,"textposition":"auto","x":[13320],"xaxis":"x","y":["google"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"microsoft","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"microsoft","offsetgroup":"microsoft","orientation":"h","showlegend":true,"textposition":"auto","x":[11837],"xaxis":"x","y":["microsoft"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"apple","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"apple","offsetgroup":"apple","orientation":"h","showlegend":true,"textposition":"auto","x":[11533],"xaxis":"x","y":["apple"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"39","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"39","offsetgroup":"39","orientation":"h","showlegend":true,"textposition":"auto","x":[9382],"xaxis":"x","y":["39"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"will","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"will","offsetgroup":"will","orientation":"h","showlegend":true,"textposition":"auto","x":[9345],"xaxis":"x","y":["will"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"samsung","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"samsung","offsetgroup":"samsung","orientation":"h","showlegend":true,"textposition":"auto","x":[7783],"xaxis":"x","y":["samsung"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"one","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"one","offsetgroup":"one","orientation":"h","showlegend":true,"textposition":"auto","x":[6599],"xaxis":"x","y":["one"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"facebook","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"facebook","offsetgroup":"facebook","orientation":"h","showlegend":true,"textposition":"auto","x":[6314],"xaxis":"x","y":["facebook"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"internet","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"internet","offsetgroup":"internet","orientation":"h","showlegend":true,"textposition":"auto","x":[5898],"xaxis":"x","y":["internet"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"said","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"said","offsetgroup":"said","orientat ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="03a52600-bd0a-4048-95a1-a3f1cb4fb2fd" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03a52600-bd0a-4048-95a1-a3f1cb4fb2fd")) {                    Plotly.newPlot(                        "03a52600-bd0a-4048-95a1-a3f1cb4fb2fd",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"us","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"us","offsetgroup":"us","orientation":"h","showlegend":true,"textposition":"auto","x":[15918],"xaxis":"x","y":["us"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"new","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"new","offsetgroup":"new","orientation":"h","showlegend":true,"textposition":"auto","x":[12770],"xaxis":"x","y":["new"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"39","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"39","offsetgroup":"39","orientation":"h","showlegend":true,"textposition":"auto","x":[12218],"xaxis":"x","y":["39"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"oil","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"oil","offsetgroup":"oil","orientation":"h","showlegend":true,"textposition":"auto","x":[10440],"xaxis":"x","y":["oil"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"reuters","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"reuters","offsetgroup":"reuters","orientation":"h","showlegend":true,"textposition":"auto","x":[9389],"xaxis":"x","y":["reuters"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"said","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"said","offsetgroup":"said","orientation":"h","showlegend":true,"textposition":"auto","x":[9038],"xaxis":"x","y":["said"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"stocks","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"stocks","offsetgroup":"stocks","orientation":"h","showlegend":true,"textposition":"auto","x":[8833],"xaxis":"x","y":["stocks"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"china","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"china","offsetgroup":"china","orientation":"h","showlegend":true,"textposition":"auto","x":[7792],"xaxis":"x","y":["china"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"will","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"will","offsetgroup":"will","orientation":"h","showlegend":true,"textposition":"auto","x":[7393],"xaxis":"x","y":["will"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"prices","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"prices","offsetgroup":"prices","orientation":"h","showlegend":true,"textposition":"auto","x":[7211],"xaxis":"x","y":["prices"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"billion","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"billion","offsetgroup":"billion","orientation":"h","showlegend":true,"textposition":" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="58c4045c-c1e6-4976-b7e2-67bc7e98c414" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58c4045c-c1e6-4976-b7e2-67bc7e98c414")) {                    Plotly.newPlot(                        "58c4045c-c1e6-4976-b7e2-67bc7e98c414",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"new","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"new","offsetgroup":"new","orientation":"h","showlegend":true,"textposition":"auto","x":[10470],"xaxis":"x","y":["new"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"video","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"video","offsetgroup":"video","orientation":"h","showlegend":true,"textposition":"auto","x":[6340],"xaxis":"x","y":["video"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"star","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"star","offsetgroup":"star","orientation":"h","showlegend":true,"textposition":"auto","x":[6273],"xaxis":"x","y":["star"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"kardashian","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"kardashian","offsetgroup":"kardashian","orientation":"h","showlegend":true,"textposition":"auto","x":[6041],"xaxis":"x","y":["kardashian"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"kim","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"kim","offsetgroup":"kim","orientation":"h","showlegend":true,"textposition":"auto","x":[5822],"xaxis":"x","y":["kim"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"you","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"you","offsetgroup":"you","orientation":"h","showlegend":true,"textposition":"auto","x":[5695],"xaxis":"x","y":["you"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"season","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"season","offsetgroup":"season","orientation":"h","showlegend":true,"textposition":"auto","x":[5433],"xaxis":"x","y":["season"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"2014","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"2014","offsetgroup":"2014","orientation":"h","showlegend":true,"textposition":"auto","x":[5313],"xaxis":"x","y":["2014"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"movie","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"movie","offsetgroup":"movie","orientation":"h","showlegend":true,"textposition":"auto","x":[4868],"xaxis":"x","y":["movie"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"will","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"will","offsetgroup":"will","orientation":"h","showlegend":true,"textposition":"auto","x":[4644],"xaxis":"x","y":["will"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"game","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"game","offsetgroup":"game","orientation":"h","showlegend":true,"textpos ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="928e29bc-796b-417c-8218-bd940eb65b39" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("928e29bc-796b-417c-8218-bd940eb65b39")) {                    Plotly.newPlot(                        "928e29bc-796b-417c-8218-bd940eb65b39",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"he","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"he","offsetgroup":"he","orientation":"h","showlegend":true,"textposition":"auto","x":[193673],"xaxis":"x","y":["he"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"trump","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"trump","offsetgroup":"trump","orientation":"h","showlegend":true,"textposition":"auto","x":[173675],"xaxis":"x","y":["trump"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"said","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"said","offsetgroup":"said","orientation":"h","showlegend":true,"textposition":"auto","x":[169475],"xaxis":"x","y":["said"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"not","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"not","offsetgroup":"not","orientation":"h","showlegend":true,"textposition":"auto","x":[121932],"xaxis":"x","y":["not"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"you","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"you","offsetgroup":"you","orientation":"h","showlegend":true,"textposition":"auto","x":[83723],"xaxis":"x","y":["you"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"will","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"will","offsetgroup":"will","orientation":"h","showlegend":true,"textposition":"auto","x":[75896],"xaxis":"x","y":["will"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"would","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"would","offsetgroup":"would","orientation":"h","showlegend":true,"textposition":"auto","x":[74904],"xaxis":"x","y":["would"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"president","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"president","offsetgroup":"president","orientation":"h","showlegend":true,"textposition":"auto","x":[65135],"xaxis":"x","y":["president"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"people","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"people","offsetgroup":"people","orientation":"h","showlegend":true,"textposition":"auto","x":[62847],"xaxis":"x","y":["people"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"one","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"one","offsetgroup":"one","orientation":"h","showlegend":true,"textposition":"auto","x":[61785],"xaxis":"x","y":["one"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"she","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"she","offsetgroup":"she","orientation":"h","showlegend":true,"textposit ...

# %%
for catcls in Category_class1:
  Visualization3(df_category_model1,catcls)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ###### **Applying N-gram & Save NumPyArrays Model #1**

# %%
ApplyNgramAndSave(df_category_model1,"model1")
# Out:
# (590037, 6718227) (196680, 6718227) (590037,) (196680,)

# %% [markdown]
# ---
#
#
# ### **MODEL #2**
#
# ---

# %%
df_category_model2=DataPreparationforML('df_category_model2.csv')

# %% [markdown]
# ###### **Visualization Model #2**

# %%
Visualization(df_category_model2)

# %%
list(set(df_category_model2["CATEGORY_CLASS_NEW"]))
# Out:
# ['GENERAL-2', 'SPORTS', 'WORLD NEWS', 'HEALTH']

# %%
Category_class2=list(set(df_category_model2["CATEGORY_CLASS_NEW"]))

# %%
for catcls in Category_class2:
  Visualization2(df_category_model2,catcls)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="98565b60-e1a9-4879-81a3-a2869441a888" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98565b60-e1a9-4879-81a3-a2869441a888")) {                    Plotly.newPlot(                        "98565b60-e1a9-4879-81a3-a2869441a888",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"you","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"you","offsetgroup":"you","orientation":"h","showlegend":true,"textposition":"auto","x":[4852],"xaxis":"x","y":["you"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"not","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"not","offsetgroup":"not","orientation":"h","showlegend":true,"textposition":"auto","x":[2175],"xaxis":"x","y":["not"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"can","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"can","offsetgroup":"can","orientation":"h","showlegend":true,"textposition":"auto","x":[1897],"xaxis":"x","y":["can"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"new","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"new","offsetgroup":"new","orientation":"h","showlegend":true,"textposition":"auto","x":[1801],"xaxis":"x","y":["new"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"women","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"women","offsetgroup":"women","orientation":"h","showlegend":true,"textposition":"auto","x":[1770],"xaxis":"x","y":["women"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"my","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"my","offsetgroup":"my","orientation":"h","showlegend":true,"textposition":"auto","x":[1770],"xaxis":"x","y":["my"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"one","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"one","offsetgroup":"one","orientation":"h","showlegend":true,"textposition":"auto","x":[1623],"xaxis":"x","y":["one"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"will","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"will","offsetgroup":"will","orientation":"h","showlegend":true,"textposition":"auto","x":[1462],"xaxis":"x","y":["will"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"like","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"like","offsetgroup":"like","orientation":"h","showlegend":true,"textposition":"auto","x":[1223],"xaxis":"x","y":["like"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"world","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"world","offsetgroup":"world","orientation":"h","showlegend":true,"textposition":"auto","x":[1203],"xaxis":"x","y":["world"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"people","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"people","offsetgroup":"people","orientation":"h","showlegend":true,"textposition":"auto","x":[1186],"xaxis":"x","y":[" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ae3bb0fa-9592-4d3b-8e0a-04dd534b110f" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae3bb0fa-9592-4d3b-8e0a-04dd534b110f")) {                    Plotly.newPlot(                        "ae3bb0fa-9592-4d3b-8e0a-04dd534b110f",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"39","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"39","offsetgroup":"39","orientation":"h","showlegend":true,"textposition":"auto","x":[15445],"xaxis":"x","y":["39"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"he","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"he","offsetgroup":"he","orientation":"h","showlegend":true,"textposition":"auto","x":[7248],"xaxis":"x","y":["he"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"ap","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"ap","offsetgroup":"ap","orientation":"h","showlegend":true,"textposition":"auto","x":[6552],"xaxis":"x","y":["ap"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"first","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"first","offsetgroup":"first","orientation":"h","showlegend":true,"textposition":"auto","x":[5481],"xaxis":"x","y":["first"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"game","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"game","offsetgroup":"game","orientation":"h","showlegend":true,"textposition":"auto","x":[5442],"xaxis":"x","y":["game"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"new","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"new","offsetgroup":"new","orientation":"h","showlegend":true,"textposition":"auto","x":[5175],"xaxis":"x","y":["new"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"will","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"will","offsetgroup":"will","orientation":"h","showlegend":true,"textposition":"auto","x":[4993],"xaxis":"x","y":["will"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"win","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"win","offsetgroup":"win","orientation":"h","showlegend":true,"textposition":"auto","x":[4958],"xaxis":"x","y":["win"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"soccer","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"soccer","offsetgroup":"soccer","orientation":"h","showlegend":true,"textposition":"auto","x":[4574],"xaxis":"x","y":["soccer"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"team","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"team","offsetgroup":"team","orientation":"h","showlegend":true,"textposition":"auto","x":[4457],"xaxis":"x","y":["team"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"world","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"world","offsetgroup":"world","orientation":"h","showlegend":true,"textposition":"auto","x":[4396],"xaxis":"x","y":["wo ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="453f7567-d459-4ba9-a8fb-96077bf8e93b" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("453f7567-d459-4ba9-a8fb-96077bf8e93b")) {                    Plotly.newPlot(                        "453f7567-d459-4ba9-a8fb-96077bf8e93b",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"39","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"39","offsetgroup":"39","orientation":"h","showlegend":true,"textposition":"auto","x":[9229],"xaxis":"x","y":["39"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"said","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"said","offsetgroup":"said","orientation":"h","showlegend":true,"textposition":"auto","x":[8525],"xaxis":"x","y":["said"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"iraq","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"iraq","offsetgroup":"iraq","orientation":"h","showlegend":true,"textposition":"auto","x":[6252],"xaxis":"x","y":["iraq"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"ap","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"ap","offsetgroup":"ap","orientation":"h","showlegend":true,"textposition":"auto","x":[6088],"xaxis":"x","y":["ap"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"reuters","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"reuters","offsetgroup":"reuters","orientation":"h","showlegend":true,"textposition":"auto","x":[5715],"xaxis":"x","y":["reuters"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"president","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"president","offsetgroup":"president","orientation":"h","showlegend":true,"textposition":"auto","x":[5081],"xaxis":"x","y":["president"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"us","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"us","offsetgroup":"us","orientation":"h","showlegend":true,"textposition":"auto","x":[4478],"xaxis":"x","y":["us"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"new","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"new","offsetgroup":"new","orientation":"h","showlegend":true,"textposition":"auto","x":[4212],"xaxis":"x","y":["new"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"two","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"two","offsetgroup":"two","orientation":"h","showlegend":true,"textposition":"auto","x":[4051],"xaxis":"x","y":["two"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"minister","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"minister","offsetgroup":"minister","orientation":"h","showlegend":true,"textposition":"auto","x":[3778],"xaxis":"x","y":["minister"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"people","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"people","offsetgroup":"people","orientation":"h","showlegend":true,"textposition": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="09afb812-5204-4712-a8c9-c77ed3cdfbe1" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09afb812-5204-4712-a8c9-c77ed3cdfbe1")) {                    Plotly.newPlot(                        "09afb812-5204-4712-a8c9-c77ed3cdfbe1",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"you","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"you","offsetgroup":"you","orientation":"h","showlegend":true,"textposition":"auto","x":[4145],"xaxis":"x","y":["you"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"ebola","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"ebola","offsetgroup":"ebola","orientation":"h","showlegend":true,"textposition":"auto","x":[3516],"xaxis":"x","y":["ebola"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"study","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"study","offsetgroup":"study","orientation":"h","showlegend":true,"textposition":"auto","x":[3348],"xaxis":"x","y":["study"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"health","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"health","offsetgroup":"health","orientation":"h","showlegend":true,"textposition":"auto","x":[3304],"xaxis":"x","y":["health"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"cancer","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"cancer","offsetgroup":"cancer","orientation":"h","showlegend":true,"textposition":"auto","x":[2919],"xaxis":"x","y":["cancer"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"new","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"new","offsetgroup":"new","orientation":"h","showlegend":true,"textposition":"auto","x":[2896],"xaxis":"x","y":["new"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"can","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"can","offsetgroup":"can","orientation":"h","showlegend":true,"textposition":"auto","x":[2415],"xaxis":"x","y":["can"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"may","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"may","offsetgroup":"may","orientation":"h","showlegend":true,"textposition":"auto","x":[2308],"xaxis":"x","y":["may"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"us","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"us","offsetgroup":"us","orientation":"h","showlegend":true,"textposition":"auto","x":[2139],"xaxis":"x","y":["us"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"not","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"not","offsetgroup":"not","orientation":"h","showlegend":true,"textposition":"auto","x":[1919],"xaxis":"x","y":["not"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"virus","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"virus","offsetgroup":"virus","orientation":"h","showlegend":true,"textposition":"auto","x":[1868],"xaxi ...

# %%
for catcls in Category_class2:
  Visualization3(df_category_model2,catcls)

# %% [markdown]
# ###### **Applying N-gram & Save NumPyArrays Model #2**

# %%
ApplyNgramAndSave(df_category_model2,"model2")
# Out:
# (141534, 1104997) (47179, 1104997) (141534,) (47179,)

# %% [markdown]
# ---
#
#
#
# ### **MODEL #3**
#
# ---

# %%
df_category_model3=DataPreparationforML('df_category_model3.csv')

# %% [markdown]
# ###### **Visualization Model #3**

# %%
Visualization(df_category_model3)

# %%
list(set(df_category_model3["CATEGORY_CLASS_NEW"]))
# Out:
# ['STYLE',
#  'TASTE',
#  'CRIME',
#  'GREEN',
#  'TRAVEL',
#  'WOMEN',
#  'ARTS & CULTURE',
#  'RELIGION',
#  'EDUCATION']

# %%
Category_class3=list(set(df_category_model3["CATEGORY_CLASS_NEW"]))

# %%
for catcls in Category_class3:
  Visualization2(df_category_model3,catcls)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1a54429a-49bf-432f-8a2d-e0cc5fb5c5b2" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a54429a-49bf-432f-8a2d-e0cc5fb5c5b2")) {                    Plotly.newPlot(                        "1a54429a-49bf-432f-8a2d-e0cc5fb5c5b2",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"you","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"you","offsetgroup":"you","orientation":"h","showlegend":true,"textposition":"auto","x":[551],"xaxis":"x","y":["you"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"fashion","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"fashion","offsetgroup":"fashion","orientation":"h","showlegend":true,"textposition":"auto","x":[241],"xaxis":"x","y":["fashion"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"new","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"new","offsetgroup":"new","orientation":"h","showlegend":true,"textposition":"auto","x":[207],"xaxis":"x","y":["new"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"can","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"can","offsetgroup":"can","orientation":"h","showlegend":true,"textposition":"auto","x":[184],"xaxis":"x","y":["can"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"best","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"best","offsetgroup":"best","orientation":"h","showlegend":true,"textposition":"auto","x":[172],"xaxis":"x","y":["best"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"week","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"week","offsetgroup":"week","orientation":"h","showlegend":true,"textposition":"auto","x":[163],"xaxis":"x","y":["week"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"like","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"like","offsetgroup":"like","orientation":"h","showlegend":true,"textposition":"auto","x":[151],"xaxis":"x","y":["like"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"beauty","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"beauty","offsetgroup":"beauty","orientation":"h","showlegend":true,"textposition":"auto","x":[149],"xaxis":"x","y":["beauty"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"style","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"style","offsetgroup":"style","orientation":"h","showlegend":true,"textposition":"auto","x":[146],"xaxis":"x","y":["style"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"look","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"look","offsetgroup":"look","orientation":"h","showlegend":true,"textposition":"auto","x":[141],"xaxis":"x","y":["look"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"hair","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"hair","offsetgroup":"hair","orientation":"h","showlegend":true,"textposition":"auto","x":[141],"xa ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e3c50402-72cd-4f1d-bbb5-5e7b1ecbd8fa" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3c50402-72cd-4f1d-bbb5-5e7b1ecbd8fa")) {                    Plotly.newPlot(                        "e3c50402-72cd-4f1d-bbb5-5e7b1ecbd8fa",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"you","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"you","offsetgroup":"you","orientation":"h","showlegend":true,"textposition":"auto","x":[868],"xaxis":"x","y":["you"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"make","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"make","offsetgroup":"make","orientation":"h","showlegend":true,"textposition":"auto","x":[324],"xaxis":"x","y":["make"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"recipes","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"recipes","offsetgroup":"recipes","orientation":"h","showlegend":true,"textposition":"auto","x":[263],"xaxis":"x","y":["recipes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"food","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"food","offsetgroup":"food","orientation":"h","showlegend":true,"textposition":"auto","x":[243],"xaxis":"x","y":["food"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"can","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"can","offsetgroup":"can","orientation":"h","showlegend":true,"textposition":"auto","x":[218],"xaxis":"x","y":["can"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"not","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"not","offsetgroup":"not","orientation":"h","showlegend":true,"textposition":"auto","x":[166],"xaxis":"x","y":["not"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"best","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"best","offsetgroup":"best","orientation":"h","showlegend":true,"textposition":"auto","x":[160],"xaxis":"x","y":["best"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"will","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"will","offsetgroup":"will","orientation":"h","showlegend":true,"textposition":"auto","x":[159],"xaxis":"x","y":["will"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"new","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"new","offsetgroup":"new","orientation":"h","showlegend":true,"textposition":"auto","x":[153],"xaxis":"x","y":["new"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"one","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"one","offsetgroup":"one","orientation":"h","showlegend":true,"textposition":"auto","x":[146],"xaxis":"x","y":["one"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"easy","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"easy","offsetgroup":"easy","orientation":"h","showlegend":true,"textposition":"auto","x":[134],"xaxis":"x","y":["easy" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f89229d7-1253-4f38-8e66-13bcafce654e" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f89229d7-1253-4f38-8e66-13bcafce654e")) {                    Plotly.newPlot(                        "f89229d7-1253-4f38-8e66-13bcafce654e",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"police","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"police","offsetgroup":"police","orientation":"h","showlegend":true,"textposition":"auto","x":[705],"xaxis":"x","y":["police"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"man","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"man","offsetgroup":"man","orientation":"h","showlegend":true,"textposition":"auto","x":[512],"xaxis":"x","y":["man"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"he","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"he","offsetgroup":"he","orientation":"h","showlegend":true,"textposition":"auto","x":[371],"xaxis":"x","y":["he"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"shooting","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"shooting","offsetgroup":"shooting","orientation":"h","showlegend":true,"textposition":"auto","x":[313],"xaxis":"x","y":["shooting"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"year","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"year","offsetgroup":"year","orientation":"h","showlegend":true,"textposition":"auto","x":[303],"xaxis":"x","y":["year"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"old","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"old","offsetgroup":"old","orientation":"h","showlegend":true,"textposition":"auto","x":[272],"xaxis":"x","y":["old"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"said","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"said","offsetgroup":"said","orientation":"h","showlegend":true,"textposition":"auto","x":[256],"xaxis":"x","y":["said"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"suspect","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"suspect","offsetgroup":"suspect","orientation":"h","showlegend":true,"textposition":"auto","x":[236],"xaxis":"x","y":["suspect"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"killed","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"killed","offsetgroup":"killed","orientation":"h","showlegend":true,"textposition":"auto","x":[221],"xaxis":"x","y":["killed"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"say","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"say","offsetgroup":"say","orientation":"h","showlegend":true,"textposition":"auto","x":[211],"xaxis":"x","y":["say"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"shot","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"shot","offsetgroup":"shot","orientation":"h","showlegend":true,"textposition":"auto"," ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="42ca06a6-f278-41f3-b72d-4799aed1d887" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42ca06a6-f278-41f3-b72d-4799aed1d887")) {                    Plotly.newPlot(                        "42ca06a6-f278-41f3-b72d-4799aed1d887",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"climate","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"climate","offsetgroup":"climate","orientation":"h","showlegend":true,"textposition":"auto","x":[646],"xaxis":"x","y":["climate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"change","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"change","offsetgroup":"change","orientation":"h","showlegend":true,"textposition":"auto","x":[368],"xaxis":"x","y":["change"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"not","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"not","offsetgroup":"not","orientation":"h","showlegend":true,"textposition":"auto","x":[243],"xaxis":"x","y":["not"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"you","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"you","offsetgroup":"you","orientation":"h","showlegend":true,"textposition":"auto","x":[234],"xaxis":"x","y":["you"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"new","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"new","offsetgroup":"new","orientation":"h","showlegend":true,"textposition":"auto","x":[228],"xaxis":"x","y":["new"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"will","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"will","offsetgroup":"will","orientation":"h","showlegend":true,"textposition":"auto","x":[227],"xaxis":"x","y":["will"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"can","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"can","offsetgroup":"can","orientation":"h","showlegend":true,"textposition":"auto","x":[217],"xaxis":"x","y":["can"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"one","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"one","offsetgroup":"one","orientation":"h","showlegend":true,"textposition":"auto","x":[197],"xaxis":"x","y":["one"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"people","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"people","offsetgroup":"people","orientation":"h","showlegend":true,"textposition":"auto","x":[194],"xaxis":"x","y":["people"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"world","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"world","offsetgroup":"world","orientation":"h","showlegend":true,"textposition":"auto","x":[192],"xaxis":"x","y":["world"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"dog","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"dog","offsetgroup":"dog","orientation":"h","showlegend":true,"textposition":"auto","x":[179],"xaxis ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="08698c6c-4cdc-45e2-bb88-e457032ec494" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08698c6c-4cdc-45e2-bb88-e457032ec494")) {                    Plotly.newPlot(                        "08698c6c-4cdc-45e2-bb88-e457032ec494",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"you","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"you","offsetgroup":"you","orientation":"h","showlegend":true,"textposition":"auto","x":[994],"xaxis":"x","y":["you"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"travel","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"travel","offsetgroup":"travel","orientation":"h","showlegend":true,"textposition":"auto","x":[355],"xaxis":"x","y":["travel"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"world","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"world","offsetgroup":"world","orientation":"h","showlegend":true,"textposition":"auto","x":[291],"xaxis":"x","y":["world"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"can","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"can","offsetgroup":"can","orientation":"h","showlegend":true,"textposition":"auto","x":[246],"xaxis":"x","y":["can"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"new","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"new","offsetgroup":"new","orientation":"h","showlegend":true,"textposition":"auto","x":[233],"xaxis":"x","y":["new"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"one","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"one","offsetgroup":"one","orientation":"h","showlegend":true,"textposition":"auto","x":[229],"xaxis":"x","y":["one"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"best","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"best","offsetgroup":"best","orientation":"h","showlegend":true,"textposition":"auto","x":[204],"xaxis":"x","y":["best"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"not","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"not","offsetgroup":"not","orientation":"h","showlegend":true,"textposition":"auto","x":[192],"xaxis":"x","y":["not"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"my","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"my","offsetgroup":"my","orientation":"h","showlegend":true,"textposition":"auto","x":[179],"xaxis":"x","y":["my"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"like","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"like","offsetgroup":"like","orientation":"h","showlegend":true,"textposition":"auto","x":[174],"xaxis":"x","y":["like"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"time","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"time","offsetgroup":"time","orientation":"h","showlegend":true,"textposition":"auto","x":[156],"xaxis":"x","y":["time"],"yaxis ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5b516f21-ec88-4a64-a750-858fe8f0a36c" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b516f21-ec88-4a64-a750-858fe8f0a36c")) {                    Plotly.newPlot(                        "5b516f21-ec88-4a64-a750-858fe8f0a36c",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"women","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"women","offsetgroup":"women","orientation":"h","showlegend":true,"textposition":"auto","x":[1374],"xaxis":"x","y":["women"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"you","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"you","offsetgroup":"you","orientation":"h","showlegend":true,"textposition":"auto","x":[1119],"xaxis":"x","y":["you"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"my","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"my","offsetgroup":"my","orientation":"h","showlegend":true,"textposition":"auto","x":[729],"xaxis":"x","y":["my"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"not","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"not","offsetgroup":"not","orientation":"h","showlegend":true,"textposition":"auto","x":[566],"xaxis":"x","y":["not"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"can","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"can","offsetgroup":"can","orientation":"h","showlegend":true,"textposition":"auto","x":[405],"xaxis":"x","y":["can"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"woman","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"woman","offsetgroup":"woman","orientation":"h","showlegend":true,"textposition":"auto","x":[351],"xaxis":"x","y":["woman"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"why","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"why","offsetgroup":"why","orientation":"h","showlegend":true,"textposition":"auto","x":[322],"xaxis":"x","y":["why"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"like","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"like","offsetgroup":"like","orientation":"h","showlegend":true,"textposition":"auto","x":[289],"xaxis":"x","y":["like"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"one","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"one","offsetgroup":"one","orientation":"h","showlegend":true,"textposition":"auto","x":[287],"xaxis":"x","y":["one"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"she","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"she","offsetgroup":"she","orientation":"h","showlegend":true,"textposition":"auto","x":[286],"xaxis":"x","y":["she"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"do","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"do","offsetgroup":"do","orientation":"h","showlegend":true,"textposition":"auto","x":[260],"xaxis":"x","y":["do"],"yaxis":"y","type":" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c4b74519-fdca-4e1d-a02b-14b59fe4550c" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4b74519-fdca-4e1d-a02b-14b59fe4550c")) {                    Plotly.newPlot(                        "c4b74519-fdca-4e1d-a02b-14b59fe4550c",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"art","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"art","offsetgroup":"art","orientation":"h","showlegend":true,"textposition":"auto","x":[533],"xaxis":"x","y":["art"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"you","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"you","offsetgroup":"you","orientation":"h","showlegend":true,"textposition":"auto","x":[464],"xaxis":"x","y":["you"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"new","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"new","offsetgroup":"new","orientation":"h","showlegend":true,"textposition":"auto","x":[341],"xaxis":"x","y":["new"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"artist","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"artist","offsetgroup":"artist","orientation":"h","showlegend":true,"textposition":"auto","x":[269],"xaxis":"x","y":["artist"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"one","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"one","offsetgroup":"one","orientation":"h","showlegend":true,"textposition":"auto","x":[250],"xaxis":"x","y":["one"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"will","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"will","offsetgroup":"will","orientation":"h","showlegend":true,"textposition":"auto","x":[226],"xaxis":"x","y":["will"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"not","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"not","offsetgroup":"not","orientation":"h","showlegend":true,"textposition":"auto","x":[217],"xaxis":"x","y":["not"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"world","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"world","offsetgroup":"world","orientation":"h","showlegend":true,"textposition":"auto","x":[200],"xaxis":"x","y":["world"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"can","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"can","offsetgroup":"can","orientation":"h","showlegend":true,"textposition":"auto","x":[192],"xaxis":"x","y":["can"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"book","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"book","offsetgroup":"book","orientation":"h","showlegend":true,"textposition":"auto","x":[162],"xaxis":"x","y":["book"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"artists","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"artists","offsetgroup":"artists","orientation":"h","showlegend":true,"textposition":"auto","x":[160],"xaxis":"x","y":[" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9099968f-3fe3-412a-bb7a-a1a855ed5980" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9099968f-3fe3-412a-bb7a-a1a855ed5980")) {                    Plotly.newPlot(                        "9099968f-3fe3-412a-bb7a-a1a855ed5980",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"pope","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"pope","offsetgroup":"pope","orientation":"h","showlegend":true,"textposition":"auto","x":[347],"xaxis":"x","y":["pope"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"not","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"not","offsetgroup":"not","orientation":"h","showlegend":true,"textposition":"auto","x":[335],"xaxis":"x","y":["not"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"you","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"you","offsetgroup":"you","orientation":"h","showlegend":true,"textposition":"auto","x":[331],"xaxis":"x","y":["you"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"my","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"my","offsetgroup":"my","orientation":"h","showlegend":true,"textposition":"auto","x":[276],"xaxis":"x","y":["my"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"church","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"church","offsetgroup":"church","orientation":"h","showlegend":true,"textposition":"auto","x":[256],"xaxis":"x","y":["church"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"people","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"people","offsetgroup":"people","orientation":"h","showlegend":true,"textposition":"auto","x":[238],"xaxis":"x","y":["people"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"francis","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"francis","offsetgroup":"francis","orientation":"h","showlegend":true,"textposition":"auto","x":[219],"xaxis":"x","y":["francis"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"can","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"can","offsetgroup":"can","orientation":"h","showlegend":true,"textposition":"auto","x":[219],"xaxis":"x","y":["can"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"god","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"god","offsetgroup":"god","orientation":"h","showlegend":true,"textposition":"auto","x":[214],"xaxis":"x","y":["god"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"religious","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"religious","offsetgroup":"religious","orientation":"h","showlegend":true,"textposition":"auto","x":[199],"xaxis":"x","y":["religious"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"muslim","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"muslim","offsetgroup":"muslim","orientation":"h","showlegend":true,"textposition":"a ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ac5055fc-3a87-4cff-a59e-3c3c93cc6486" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac5055fc-3a87-4cff-a59e-3c3c93cc6486")) {                    Plotly.newPlot(                        "ac5055fc-3a87-4cff-a59e-3c3c93cc6486",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"education","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"education","offsetgroup":"education","orientation":"h","showlegend":true,"textposition":"auto","x":[353],"xaxis":"x","y":["education"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"school","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"school","offsetgroup":"school","orientation":"h","showlegend":true,"textposition":"auto","x":[332],"xaxis":"x","y":["school"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"students","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"students","offsetgroup":"students","orientation":"h","showlegend":true,"textposition":"auto","x":[225],"xaxis":"x","y":["students"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"you","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"you","offsetgroup":"you","orientation":"h","showlegend":true,"textposition":"auto","x":[200],"xaxis":"x","y":["you"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"not","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"not","offsetgroup":"not","orientation":"h","showlegend":true,"textposition":"auto","x":[184],"xaxis":"x","y":["not"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"teachers","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"teachers","offsetgroup":"teachers","orientation":"h","showlegend":true,"textposition":"auto","x":[173],"xaxis":"x","y":["teachers"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"schools","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"schools","offsetgroup":"schools","orientation":"h","showlegend":true,"textposition":"auto","x":[162],"xaxis":"x","y":["schools"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"can","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"can","offsetgroup":"can","orientation":"h","showlegend":true,"textposition":"auto","x":[140],"xaxis":"x","y":["can"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"my","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"my","offsetgroup":"my","orientation":"h","showlegend":true,"textposition":"auto","x":[128],"xaxis":"x","y":["my"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"teacher","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"teacher","offsetgroup":"teacher","orientation":"h","showlegend":true,"textposition":"auto","x":[111],"xaxis":"x","y":["teacher"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"do","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"do","offsetgroup":"do","orientation":"h","showle ...

# %%
for catcls in Category_class3:
  Visualization3(df_category_model3,catcls)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ###### **Applying N-gram & Save NumPyArrays Model #3**

# %%
ApplyNgramAndSave(df_category_model3,"model3")
# Out:
# (29178, 216227) (9727, 216227) (29178,) (9727,)

# %% [markdown]
# # **Data Preparation for Deep Learning**

# %% [markdown]
# ### **Help Methods**

# %%
vocabulary_size = 15000
max_text_len = 768
stemmer = SnowballStemmer('english')
stop_words = [word for word in stopwords.words('english') if word not in ["my","haven't","aren't","can","no", "why", "through", "herself", "she", "he", "himself", "you", "you're", "myself", "not", "here", "some", "do", "does", "did", "will", "don't", "doesn't", "didn't", "won't", "should", "should've", "couldn't", "mightn't", "mustn't", "shouldn't", "hadn't", "wasn't", "wouldn't"]]

# %%
def preprocess_text(text):
    text = re.sub('[^a-zA-Z]', ' ', text)
    words = text.lower().split()
    words = [stemmer.stem(word) for word in words if not word in stop_words]
    cleaned_text = ' '.join(words)
    return cleaned_text

# %%
def DataPreparationforDL(filename,model,category_class):
  df_category_model = pd.read_csv(datafolder+filename)
  df_category_model.drop(columns=['Unnamed: 0'],inplace=True)
  df_category_model['TITLE']=df_category_model['TITLE'].fillna("")
  df_category_model['cleaned_text'] = df_category_model['TITLE'].apply(preprocess_text)
  tokenizer = Tokenizer(num_words=vocabulary_size)
  tokenizer.fit_on_texts(df_category_model['cleaned_text'].values)
  le = len(tokenizer.word_index) + 1
  print(le)
  sequences = tokenizer.texts_to_sequences(df_category_model['cleaned_text'].values)
  X_DeepLearning = pad_sequences(sequences, maxlen=max_text_len)
  labl=0
  category_class=list(set(df_category_model['CATEGORY_CLASS_NEW']))
  for catcls in category_class:
    df_category_model.loc[df_category_model['CATEGORY_CLASS_NEW'] == catcls , 'LABEL'] = labl
    labl=labl+1
  labels = to_categorical(df_category_model['LABEL'], num_classes=labl)
  XX_train, XX_test, y_train, y_test = train_test_split(X_DeepLearning , labels, test_size=0.25, random_state=42)
  print((XX_train.shape, y_train.shape, XX_test.shape, y_test.shape))
  joblib.dump(XX_train, arrayfolder+'XX_train_'+model+'_d.pkl')
  joblib.dump(XX_test, arrayfolder+'XX_test_'+model+'_d.pkl')
  joblib.dump(y_train, arrayfolder+'yy_train_'+model+'_d.pkl')
  joblib.dump(y_test, arrayfolder+'yy_test_'+model+'_d.pkl')
  joblib.dump(X_DeepLearning, arrayfolder+'X_DeepLearning_'+model+'_d.pkl')
  joblib.dump(sequences, arrayfolder+'sequences_'+model+'_d.pkl')
  joblib.dump(vocabulary_size, arrayfolder+'vocabulary_size_'+model+'_d.pkl')
  joblib.dump(max_text_len, arrayfolder+'max_text_len_'+model+'_d.pkl')

# %% [markdown]
# ---
#
# ### **MODEL #1**
#
# ---

# %%
Category_class1=['BUSINESS', 'ENTERTAINMENT', 'GENERAL-1', 'POLITICS', 'SCIENCE & TECHNOLOGY']
DataPreparationforDL('df_category_model1.csv','model1',Category_class1)
# Out:
# 167648
# ((590037, 768), (590037, 5), (196680, 768), (196680, 5))

# %% [markdown]
# ---
#
# ### **MODEL #2**
#
# ---

# %%
Category_class2=['GENERAL-2', 'HEALTH', 'SPORTS', 'WORLD NEWS']
DataPreparationforDL('df_category_model2.csv','model2',Category_class2)
# Out:
# 46758
# ((141534, 768), (141534, 4), (47179, 768), (47179, 4))

# %% [markdown]
# ---
#
# ### **MODEL #3**
#
# ---

# %%
Category_class3=['ARTS & CULTURE', 'CRIME', 'EDUCATION', 'GREEN', 'RELIGION', 'STYLE', 'TASTE', 'TRAVEL', 'WOMEN']
DataPreparationforDL('df_category_model3.csv','model3',Category_class3)
# Out:
# 21306
# ((29178, 768), (29178, 9), (9727, 768), (9727, 9))
